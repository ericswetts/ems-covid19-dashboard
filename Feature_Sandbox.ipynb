# %%
from flask_sqlalchemy import SQLAlchemy
from pandas.io.parsers import read_csv
import plotly.express as px
import plotly.graph_objects as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
import pandas as pd
import numpy as np
import json
import requests
import dash_table
import jupyter_dash as JupyterDash
import random as r


#for Heroku Flask deployment
from flask_sqlalchemy import SQLAlchemy
from flask import Flask
from jupyter_dash import JupyterDash

import dash_bootstrap_components as dbc

import locale
locale.setlocale(locale.LC_ALL, '')  # Use '' for auto, or force e.g. to 'en_US.UTF-8'

# external_stylesheets = [dbc.themes.YETI]

# %% [markdown]
# ### FULL APP AS OF 7/1/2021

# %%
# #Population Dropdown
# metric_dropdown = dbc.Col(
#     dcc.Dropdown(
#         id = 'population-dropdown',
#         options= [
#             {'label': '< 5 Million' , 'value': 2},
#             {'label': '5-10 Million', 'value': 1},
#             {'label': 'More than 5 Million', 'value': 0}
#         ],
#         value=[],
#         multi=True,
#         optionHeight = 25
#     ),
#     xs = 12,
#     md = 5, 
# )

# %%
#LOAD WHEN WEBSITE LOADS

country_reference = pd.read_csv('/Users/ems/Documents/Coronavirus_Dashboard/geodata/country_reference.csv')
df = pd.read_csv('/Users/ems/Documents/df.csv', parse_dates = ['Date'])
available_countries = country_reference.loc[(country_reference['ISO-3'].isin(df['ISO-3'])), ['Country', 'ISO-3']].drop_duplicates().values

# %%
#parse date (sigh)
# country_data['Date'] =  pd.to_datetime(country_data['Date'].str.slice(0,10)) # + " " + country_data['Date'].str.slice(11, -1)
# country_data['Month and Year'] = pd.DatetimeIndex(country_data['Date']).strftime("%b %Y")



country_card_list = dbc.Col(
    id = 'country-card-list',
    style = {
#         'border': 'none', 
        'fontSize' : '14px',
        'backgroundColor' : '#ede7c6',
        'paddingTop' : '20px' 
    },
    width = 4
)

# %%
#Country Dropdown
country_dropdown_country = dbc.Col( 
    children = [
        html.Label(html.H5('Countries')),
        dcc.Dropdown(
            id = 'country-dropdown-country',
            options = [{'label': country, 'value' : iso} for country, iso in available_countries],
            style = {'fontSize': '14px'}, 
            value = 'USA', 
            optionHeight = 22, 
            clearable = False
        )
    ],
    xs = 12,
    md = 6,
)

# %%
#Choropleth Map for Country Tab
focus_map = dbc.Col(
    dcc.Graph(id = 'focus-map'), 
    width = 8, 
    style={'position':'relative', 'zIndex':'1', 'paddingTop' : '20px'}, 
    
)

region_line = dbc.Col(
    dcc.Graph(id = 'region-line'),
    width = 12
)

# %%
#Tabs
country_card_description = dbc.Col(id = 'country-card-description', width = 12)

country_tab =  dcc.Tab(
    id = 'country-tab',
    value = 'country-tab',
    label='Country Focus',  
    children = dbc.Container(
        [dbc.Row([focus_map, country_card_list]),
        dbc.Row(country_card_description), 
        dbc.Row(region_line)])
)

global_tab = dcc.Tab(id = 'global-tab', 
                     label='Global Overview', 
                     value='global-tab')
        
tabs = dcc.Tabs(
        id = 'tabs', 
        value='country-tab', 
        children=[country_tab, global_tab], 
        colors={ "border": "#2F4F4F", "primary": "ede712", "background": "#ede7c6" }
)

controls_global = html.Div([
        dbc.Container([
            dbc.Row([
    html.H5('GLOBAL!!!')
            ])]
        ),
    ], 
        id  = 'controls-global'
)

controls_country = html.Div([
        dbc.Container([
            dbc.Row([
                country_dropdown_country,
                metric_dropdown_country,
            ]),
            ]
        ),
    ], 
        id = 'controls-country'
)

controls_container = html.Div(
    id = 'controls-container', 
    className = 'controls',
    children = [controls_country, controls_global])

# %%
metric_dropdown_country = dbc.Col(
    children = [
    html.Label(html.H5('Select a Country')),   
    dcc.Dropdown(
        id = 'metric-dropdown-country',
        options = [
            # Confirmed Case Metrics
            {'label':'Cumulative Cases', 'value': 'Cases'},
            {'label':'Cumulative Cases per 1M', 'value': 'Cases per 1M'}, 
            {'label':'Daily Cases (n)', 'value': 'New Cases (n)'},
            {'label':'Daily Cases (Smoothed)', 'value':'New Cases (SMA)'},

            #Confirmed Death Metrics
            {'label':'Cumulative Deaths', 'value': 'Deaths'},
            {'label':'Cumulative Deaths per 1M', 'value': 'Deaths per 1M'},
            {'label':'Daily Deaths (n)', 'value': 'New Deaths (n)'},
            {'label':'Daily Deaths (Smoothed)', 'value':'New Deaths (SMA)'},
        ],
    value='Cases',
    optionHeight = 22
    )
    ],
    xs = 12,
    md = 6, 
)

# %%
##START APP
app = JupyterDash(__name__, external_stylesheets = external_stylesheets)

app.layout = html.Div([
    controls_container,
    tabs
])

@app.callback(
    Output('controls-container', 'children'),
    Input('tabs', 'value')
)
def populate_controls(tab):
    if tab == 'global-tab':
        return controls_global
    return controls_country

@app.callback(
    Output('focus-map', 'figure'),
    [Input('country-dropdown-country', 'value'),
    Input('metric-dropdown-country', 'value')]
)
def update_country_map(iso3, new_metric):
    
    #Helper Function for color scale
    def max_range(x,y):
        return (x if x > y else y)
    
    #Helper Function
    def metric_for_map(new_metric):
        if new_metric == 'New Cases (SMA)' : return 'New Cases (n)'
        if new_metric == 'New Deaths (SMA)' : return 'New Deaths (n)'
        return new_metric
    
    new_metric = metric_for_map(new_metric)
    
    filtered_df = df.loc[(df['Date']  == df['Date'].max())]
    
    #Centering and Zoom height variables
    projection = country_reference.loc[country_reference['ISO-3'] == iso3, 'Projection'].item()
    lat = country_reference.loc[country_reference['ISO-3'] == iso3, 'Lat'].item()
    lon = country_reference.loc[country_reference['ISO-3'] == iso3, 'Lon'].item()
    color_scale_min = filtered_df[new_metric].min()
    color_scale_max = max_range(filtered_df[new_metric].max(), 200)
    
    fig = px.choropleth(filtered_df,
                locations = "ISO-3",               
                color = new_metric,
                hover_name = "Country",  
                color_continuous_scale = 'algae',
                range_color = (color_scale_min, color_scale_max),
                title = '{} by Country'.format(new_metric), 
                template = 'plotly_white'
    )
   
    # Custom fitbounds using center properties
    fig.update_geos(center_lon = lon, center_lat = lat)
    fig.update_geos(lataxis_showgrid=True, lonaxis_showgrid=True)
    
    fig.update_geos(projection_type="natural earth")
    fig.update_layout(height=450, margin={"r":10,"t":30,"l":10,"b":30})
    fig.update_layout(transition_duration=500)
    fig.update_layout(title_x=0.3, title_font_size = 16)
    fig.update_layout(coloraxis_colorbar = dict(thickness = 8))
    fig.update_geos(projection_scale=projection)
    
    return fig

@app.callback(
    [Output('country-card-description', 'children'),
    Output('country-card-list', 'children'),
    Output('region-line', 'figure')],
    [Input('country-dropdown-country', 'value'),
     Input('metric-dropdown-country', 'value')]
)
def update_country_card(iso3, new_metric):
    
    #helper method for card text
    def trend(n): return "increased" if n > 1 else 'decreased'

    new_country =  country_reference.loc[country_reference['ISO-3'] == iso3, 'Country'].iloc[0]
    df_c = df[df['ISO-3'] == iso3]
    last_two_weeks = df_c.loc[:, ['New Deaths (SMA)','New Cases (SMA)', 'Date']].tail(14)
    print(last_two_weeks)
    pct_deaths_two_weeks = round((last_two_weeks.loc[:,'New Deaths (SMA)'].iloc[0] / last_two_weeks.loc[:,'New Deaths (SMA)'].iloc[13] * 100 ) - 100, 2)
    pct_cases_two_weeks = round((last_two_weeks.loc[:,'New Cases (SMA)'].iloc[0] / last_two_weeks.loc[:,'New Cases (SMA)'].iloc[13] * 100) - 100, 2)
    days_since_first_case = (df_c['Date'].max() - df_c['Date'].min()).days
    first_case_date = df_c.loc[(df_c['Cases'] > 0), ['Date']].iloc[0].dt.strftime('%B %d, %Y').iloc[0]
    country_cases = df_c.loc[:,['Cases']].iloc[-1][0]
    country_deaths = df_c.loc[:,['Deaths']].iloc[-1][0]
    country_cases_per_1m = df_c.loc[:,['Deaths per 1M']].iloc[-1][0] 
    country_deaths_per_1m = df_c.loc[:,['Cases per 1M']].iloc[-1][0]

    new_cases = df_c.loc[:,['New Cases (n)']].astype('int').iloc[-1][0]
    under_control = "widespread" if new_cases > 500 else "limited"
    
    
    #Regional Line Chart Variable
    group = country_reference.loc[country_reference['ISO-3'] == iso3, 'Group'].iloc[0]


# Non-COVID19 Country Data
    wfpi_score = country_reference.loc[country_reference['ISO-3'] == iso3, 'WPFI Score'].iloc[0]
    wfpi_rank = country_reference.loc[country_reference['ISO-3'] == iso3, 'WPFI Rank'].iloc[0]
    wfpi_max_rank = country_reference['WPFI Rank'].max()
    country_life_exp = country_reference.loc[country_reference['ISO-3'] == iso3, 'Life Exp 2018'].round(2).iloc[0]

    country_card_text = "{} reported its first case on {}. The country has reported a total of {} cases and {} deaths. \
    Currently, COVID-19 transmission is {} in {}, as the number of new cases per day is {}. \
    In the past two weeks, the average daily case count in {} has {} by {}%, and the death rate has {} by {}%."\
        .format(new_country, first_case_date, country_cases, country_deaths, under_control, new_country, new_cases, new_country,
               trend(pct_cases_two_weeks), pct_cases_two_weeks, trend(pct_deaths_two_weeks), pct_deaths_two_weeks)
    
    country_card_description_content = dbc.Card(
            [html.H3('Country Overview', className = 'card-title'),
            html.P(country_card_text, className = 'card-text')
            ], 
            style = {'border': 'none'}
        )

    country_card_list_content = dbc.ListGroup(
            dbc.ListGroupItem(
                children = [
                    dbc.ListGroupItemHeading(html.H4('{} Summary'.format(new_country))),
                    html.Hr(),
#                     dbc.ListGroupItemHeading(country_card_text),
#                     html.Hr(),
                    dbc.ListGroupItemHeading("Statistics"),
                    dbc.ListGroupItemText(f"Total Cases : {int(country_cases):n}"),
                    dbc.ListGroupItemText(f"Cases per 1M : {int(country_cases_per_1m):n}"),
                    dbc.ListGroupItemText(f"Total Deaths : {int(country_deaths):n}"),
                    dbc.ListGroupItemText(f"Deaths per 1M : {int(country_deaths_per_1m):n}"),
                    dbc.ListGroupItemText(f"Life Expectancy (2018) : {country_life_exp} years"),
                    dbc.ListGroupItemText(f"Press Freedom Index Rank (2020) : {int(wfpi_rank)} out of {int(wfpi_max_rank)}"),
                    dbc.ListGroupItemText(f"United Nations Regional Grouping : {group}")

                ], 
                style = {'color': '#2f4f4f', 'backgroundColor' : '#ede7c6' }
            ),
        flush = True
    )
    
    #Line Chart

    group_isos = country_reference.loc[country_reference['Group'] == group, ['ISO-3']].values.flatten()
    line_chart_df = df.loc[df['ISO-3'].isin(group_isos)]


    line_chart_region = px.line(line_chart_df,
        x = 'Date', 
        y = new_metric, 
        title = '{}, {} Region'.format(new_metric, group), # line_chart_titles[new_metric], 
        color = 'Country',
        text = new_metric, 
        template='gridon', 
        log_y = True,
        labels = dict(
            x = 'Date', 
            y = 'Cases', # str(new_metric).title(),
            country = 'Country')
        )

    line_chart_region.update_traces(mode='lines')
    line_chart_region.update_layout(hovermode='closest', font_size = 14, title_font_size = 16)
    line_chart_region.update_layout(height = 500)
    
    return (country_card_description_content, country_card_list_content, line_chart_region)


import random
a = random.randint(1000,5000)
app.run_server(mode = 'external', debug = True, port = a)

# %% [markdown]
# fitbounds
# Code: fig.update_geos(fitbounds=<VALUE>)
# Type: enumerated , one of ( False | "locations" | "geojson" )
# Determines if this subplot's view settings are auto-computed to fit trace data. On scoped maps, setting `fitbounds` leads to `center.lon` and `center.lat` getting auto-filled. On maps with a non-clipped projection, setting `fitbounds` leads to `center.lon`, `center.lat`, and `projection.rotation.lon` getting auto-filled. On maps with a clipped projection, setting `fitbounds` leads to `center.lon`, `center.lat`, `projection.rotation.lon`, `projection.rotation.lat`, `lonaxis.range` and `lonaxis.range` getting auto-filled. If "locations", only the trace's visible locations are considered in the `fitbounds` computations. If "geojson", the entire trace input `geojson` (if provided) is considered in the `fitbounds` computations, Defaults to "False".

# %% [markdown]
# #Dashboard Components
# ### * Country Level
# * Bar chart with new cases (bars) and deaths (red line)
# * Choropleth Maps that focuses in on the country??
# * Line Charts showing cumulative cases & cumulative deaths in region
# * Country profile
#   * First Case Date
#   * Number of cases
#   * Number of deaths
#   * last 2 weeks trend
#   * Regional grouping - data cleaned and merged
#   * Trustwiorthiness data - data cleaned and merged
# * Controls
#   * Country Selector (single) - Done
#
# ### * Global
# * Choropleth Map - Done
# * Global Fast Facts - In Progress
#   * Add 'Country with fastest growing infection rate per 1M'
#     * (cases per 1m (today) / cases per 1m (2 weeks ago) * 100
# * Mobility Data
#
# <!-- * Top 15 Data Table -->
# * Controls
#   * Time slider
#   * Country Selector (multiple)
#   * Metrics Selector

# %%
fig = px.bar(df, x="Date", y="New Deaths (n)", color="Country", title="Long-Form Input")
# fig.show()

# %%
## choropleth 2nd layer (in progress - see choropleth_mapbox (requires api key and geojson) for next steps
    selected_country_df = filtered_df.loc[filtered_df['ISO-3'] == iso3]
    
    fig.add_trace(
        px.choropleth_mapbox(selected_country_df, 
                    locations = "ISO-3",               
                    color = new_metric,
                    hover_name = "Country",  
                    color_continuous_scale = 'algae',
                    range_color = (color_scale_min, color_scale_max),
                    template = 'plotly_white'
                                )
    )

# %%
df = pd.read_csv('/Users/ems/Documents/df.csv', parse_dates = ['Date'])

# %%
#To update the current dataset and pull in fresh data (for joining it to other sheets)

df = pd.read_csv('/Users/ems/Documents/df.csv', parse_dates = ['Date'])

df['Month and Year'] = pd.DatetimeIndex(df['Date']).strftime("%b %Y")

iso3_list = pd.read_csv('Coronavirus_Dashboard/geodata/ISO3.csv')
coords = pd.read_csv('Coronavirus_Dashboard/geodata/country_coordinates.csv').drop(['Country','Alpha-2', 'Num_code'], axis = 1)
un_regions = pd.read_csv('Coronavirus_Dashboard/geodata/UN_Regions.csv', skiprows = 1).drop('Country', axis = 1)
press_freedom_index = pd.read_csv('Coronavirus_Dashboard/geodata/WPFI.csv', skiprows = 1).drop('Country', axis = 1).rename(columns={'Rank': 'WPFI Rank', 'Score': 'WPFI Score'})
life_exp = pd.read_csv('Coronavirus_Dashboard/geodata/life_exp_2018.csv', skiprows = 4).loc[:, ['Country Code', '2018']].rename(columns = {'Country Code': 'ISO-3', '2018': 'Life Exp 2018'})
landmass = pd.read_csv('Coronavirus_Dashboard/geodata/landmass.csv').rename(columns = {'projection':'Projection'}).drop(['Country', 'Rank', 'sq_km', 'zoom_score'], axis = 1)
income_group = pd.read_csv('Coronavirus_Dashboard/geodata/wb_income_group.csv').drop(columns = ['id', 'Lending category', 'Other']).rename(columns = {'Region': 'WB Region', 'Code' : 'ISO-3', 'Income group' : 'Income Group'})
country_reference = iso3_list.merge(un_regions, on = 'ISO-3', how = 'left')\
    .merge(coords, on = 'ISO-3', how = 'left')\
    .merge(press_freedom_index, on = 'ISO-3', how = 'left')\
    .merge(life_exp, how = 'left', on = 'ISO-3')\
    .merge(landmass, on = 'ISO-3', how = 'left')\
    .merge(income_group, on = 'ISO-3', how = 'left')
    
country_reference.to_csv('Coronavirus_Dashboard/geodata/country_reference.csv')

# %%
country_reference

# %%
line_chart_region = dcc.Graph(id = 'line-chart-region')
line_chart_region_df = d

        fig = px.line(line_chart_region_df,
        x = 'Date', 
        y = new_metric, 
        title = line_chart_titles[new_metric], 
        color = 'Country',
        text = new_metric, 
        template='gridon', 
        log_y = False,
        labels = dict(
            x = 'Date', 
            y = str(new_metric).title(),
            country = 'Country')
        )

# %%
import dash_bootstrap_components.themes

# %%
group = country_reference.loc[country_reference['ISO-3'] == 'USA', 'Group'].iloc[0]
countries_in_group = country_reference.loc[country_reference['Group'] == group, ['ISO-3']]

# %%
df['Country']

# %%
group = country_reference.loc[country_reference['ISO-3'] == 'USA', 'Group'].iloc[0]
group_isos = country_reference.loc[country_reference['Group'] == group, ['ISO-3']].values.flatten()
line_chart_df = df.loc[df['ISO-3'].isin(group_isos)]

# %%
df_filtered = df.loc[df['Date'] == df['Date'].max(), ['Cases per 1M', 'Country', 'ISO-3', 'Population']]
income_groups = country_reference.loc[:, ['ISO-3', 'Income Group']]
df_box = df_filtered.merge(income_groups, how = 'left', on = 'ISO-3', copy = False)
df_box['Income Group'].fillna('', inplace = True)

import plotly.graph_objects as go
import plotly.express as px


# fig = px.box(df_box, y="Cases per 1M", points="all", color='Country', verty = False)
# fig.show()
                  
                  
# box = go.Figure(data=)

# box.update_layout(yaxis_type = 'log')
# box.show()

order = ['Low income', 'Lower middle income', 'Upper middle income', 'High income']
fig = px.box(df_box, 
             x="Cases per 1M", 
             points="all", 
             hover_data=['Country'], 
             color = 'Income Group',
#              boxmode = 'overlay',
             orientation = 'h', 
             log_x = True,
             category_orders = {'Income group' : order},
             width = 1000
#              theme = 'plotly white'
            )

fig.show()

# %%
import plotly.graph_objects as go

new_metric = 'Cases per 1M'
fig = go.Figure()
fig.update_layout(margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ))
fig.update_layout(title = str(new_metric) + ' ' + 'Distribution by World Bank Income Group')
fig.update_layout(xaxis_type = 'log', 
#                   height = 800, 
                  legend=dict(
                        x=0,
                        y=1,
                        traceorder='normal',
                        font=dict(size=12),
    ))

colors = ['#3DA5D9', '#73BFB8', '#EA7317', '#D44D5C']
order = ['Low income', 'Lower middle income', 'Upper middle income', 'High income']

i = 0
df_box['pop_norm'] = (40-5) * (df_box['Population'] - df_box['Population'].min()) / (df_box['Population'].max() - df_box['Population'].min()) + 5
print(df_box.describe())
    
for grp in order:

    data = df_box.loc[df_box['Income Group'] == grp]
    data['metric'] = data[new_metric].name
    data['jitter'] = np.random.randint(0,7, size=len(data)) + (20 * i)
    data['pop_norm'].describe()
    #Custom hovertemplate data for scatterplot
    cd = np.stack((data['Country'], data['metric'], data['Income Group']), axis=-1)
    
    
    fig.add_trace(go.Box(
        x = data[new_metric],
        y = data['Income Group'],
        name=str(grp),
#         pointpos=0,
        orientation = 'h',
        boxpoints= None, # represent all points
#         marker_color= "#ffffff",
        line_color=colors[i]
    ))
   
    fig.update_layout( bargap = 1, xaxis_type = 'log')
    fig.update_layout(template='plotly_white')
    
    fig.add_trace(go.Scatter(
        x = data[new_metric],
        y = data['jitter'],
        mode = 'markers', 
        orientation = 'h',
        marker=dict(size = data['pop_norm'], color = colors[i], line = dict( width = 2, color = 'black')),
        showlegend = False, 
        customdata = cd
#         showxaxis = False, 
#         x0=10, 
#         dx=1,
# #         y = [1,2,3,4]
    ))
    fig.update_traces(hovertemplate= "<br>".join(["<b>Country:</b> %{customdata[0]}", 
                                                  "<b>Metric:<b> %{customdata[1]}",
                                                 "<b>Income Group:</b> %{customdata[2]}"]))
         
    i += 1

fig.update_yaxes(visible=False)
fig.show()

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Only Whiskers",
#     boxpoints=False, # no data points
#     marker_color='rgb(9,56,125)',
#     line_color='rgb(9,56,125)',
#     orientation = 'h'
# ))

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Suspected Outliers",
#     boxpoints='suspectedoutliers', # only suspected outliers
#     marker=dict(
#         color='rgb(8,81,156)',
#         outliercolor='rgba(219, 64, 82, 0.6)',
#         line=dict(
#             outliercolor='rgba(219, 64, 82, 0.6)',
#             outlierwidth=2)),
#     line_color='rgb(8,81,156)'
# ))

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Whiskers and Outliers",
#     boxpoints='all', # represent all points
#     marker_color='rgb(107,174,214)',
#     line_color='rgb(107,174,214)'
# ))

# %%
#Horizontal

import plotly.graph_objects as go

new_metric = 'Cases per 1M'

fig = go.Figure()
fig.update_layout(
    margin=dict(
        l=30,
        r=30,
        b=30,
        t=50,
        pad=20
    ),
    yaxis_type = 'log', 
    yaxis_title = 'Cases')
fig.update_layout(title = str(new_metric) + ' ' + 'Distribution by World Bank Income Group')
fig.update_layout( legend=dict(
        x=0,
        y=1,
        traceorder='normal',
        font=dict(
            size=12,),
    ))

colors = ['#3DA5D9', '#73BFB8', '#EA7317', '#D44D5C']
order = ['Low income', 'Lower middle income', 'Upper middle income', 'High income']

i = 0
df_box['pop_norm'] = (40-5) * (df_box['Population'] - df_box['Population'].min()) / (df_box['Population'].max() - df_box['Population'].min()) + 5
print(df_box.describe())
    
for grp in order:

    data = df_box.loc[df_box['Income Group'] == grp]
    data['metric'] = data[new_metric].name
    data['jitter'] = np.random.randint(0,7, size=len(data)) + (20 * i)
    data['jitter'] = np.where(data['Population'] == data['Population'].mean(), data['jitter'].median(), data['jitter'] )
    data['pop_norm'].describe()
    #Custom hovertemplate data for scatterplot
    cd = np.stack((data['Country'], data['metric'], data['Income Group'], data['metric']), axis=-1)
    
    
    fig.add_trace(go.Box(
        x = data['Income Group'],
        y = data[new_metric],
        name=str(grp),
        orientation = 'v',
        pointpos= 0, # Shows data point 
        boxpoints= None, # represent all points
        fillcolor = colors[i],
        line=dict( width = 2, color = 'black'),
        width = 1

    ))
   
    fig.update_layout( bargap = 1)

    fig.update_layout(template='plotly_white')
    
    fig.add_trace(go.Scatter(
        y = data[new_metric],
        x = data['jitter'],
        mode = 'markers', 
        orientation = 'v',
        marker=dict(size = data['pop_norm'], color = colors[i], line = dict( width = 2, color = 'black')),
        showlegend = False, 
        customdata = cd
#         showxaxis = False, 
#         x0=10, 
#         dx=1,
# #         y = [1,2,3,4]
    ))
    fig.update_traces(hovertemplate= "<br>".join(["<b>Country</b>: %{customdata[0]}", 
                                                  "<b>customdata[3]}</b>: %{customdata[1]}",
                                                 "<b>Income Group</b>: %{customdata[2]}"]))
         
    i += 1

fig.update_xaxes(visible=False)

fig.show()

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Only Whiskers",
#     boxpoints=False, # no data points
#     marker_color='rgb(9,56,125)',
#     line_color='rgb(9,56,125)',
#     orientation = 'h'
# ))

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Suspected Outliers",
#     boxpoints='suspectedoutliers', # only suspected outliers
#     marker=dict(
#         color='rgb(8,81,156)',
#         outliercolor='rgba(219, 64, 82, 0.6)',
#         line=dict(
#             outliercolor='rgba(219, 64, 82, 0.6)',
#             outlierwidth=2)),
#     line_color='rgb(8,81,156)'
# ))

# fig.add_trace(go.Box(
#     y=[0.75, 5.25, 5.5, 6, 6.2, 6.6, 6.80, 7.0, 7.2, 7.5, 7.5, 7.75, 8.15,
#         8.15, 8.65, 8.93, 9.2, 9.5, 10, 10.25, 11.5, 12, 16, 20.90, 22.3, 23.25],
#     name="Whiskers and Outliers",
#     boxpoints='all', # represent all points
#     marker_color='rgb(107,174,214)',
#     line_color='rgb(107,174,214)'
# ))

# %%
# Testing (again) db api methods
#!/usr/bin/env python
# coding: utf-8

# In[23]:


import psycopg2
from io import StringIO
import os
import pandas as pd
import requests
import os

from process_data import json_to_df, create_chart_ready_df


def connect():
    DATABASE_URL = os.environ['DATABASE_URL']
    
    # Connect to the PostgreSQL database server 
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(DATABASE_URL, sslmode='require')
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn


def get_from_db(table):

    try:
        conn = connect()
        Cursor = conn.cursor()
        
    except Exception as e:
        print('Unable to connect to db. Please check credentials.')
        return e
        
    try:
        Cursor.execute('Select * from {}'.format(table))
    except Exception as e:
        print('Unable to execute SQL query. Rolling back query...')
        Cursor.execute('rollback')
        return e
        
    results = Cursor.fetchall()
    Cursor.close()
    return results

    
def set_to_db (df, table):
    conn = connect()
    Cursor = conn.cursor()
    try:
        Cursor.execute('DELETE FROM {};'.format(table))
        print('Successfully cleared cached data')
    except Exception as e:
        print(f'Failed to clear cached data : {e} ')
    copy_from_stringio(conn, df, table)
    Cursor.close()
    
    
#helper method to set data to db
def copy_from_stringio(conn, df, table):
    """
    Here we are going save the dataframe in memory 
    and use copy_from() to copy it to the table
    """
    # save dataframe to an in memory buffer
    buffer = StringIO()
    df.to_csv(buffer, index_label = 'id', header=False)
    print(df.columns)
    buffer.seek(0)
    
    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("Successfully posted to DB")
    cursor.close()
    
#API get method
def get_from_api():
    try:
        json_url = 'https://coronavirus-tracker-api.herokuapp.com/v2/locations?timelines=1'
        response = requests.get(json_url)

        print(response)
        timeline_json = response.json()
        return timeline_json
    
    except Exception as e:
        print('Error making API call: ', e)
        return e

# %%
url = 'https://jsonplaceholder.typicode.com/todos/1'
url2 = 'https://coronavirus-tracker-api.herokuapp.com/v2/locations'

# %%
# data = get_from_api()
# new_df = json_to_df(data)
new_df
# Out:
#             Date  Deaths  Cases      Country Country Code  Population  \
# 0     2020-01-22       0      0  Afghanistan           AF    37172386
# 1     2020-01-23       0      0  Afghanistan           AF    37172386
# 2     2020-01-24       0      0  Afghanistan           AF    37172386
# 3     2020-01-25       0      0  Afghanistan           AF    37172386
# 4     2020-01-26       0      0  Afghanistan           AF    37172386
# ...          ...     ...    ...          ...          ...         ...
# 97642 2021-01-14     636  25368     Zimbabwe           ZW    14439018
# 97643 2021-01-15     666  26109     Zimbabwe           ZW    14439018
# 97644 2021-01-16     683  26881     Zimbabwe           ZW    14439018
# 97645 2021-01-17     713  27203     Zimbabwe           ZW    14439018
# 97646 2021-01-18     773  27892     Zimbabwe           ZW    14439018
#
#       Province    Latitude  Longitude  Cases per 1M  Deaths per 1M  \
# 0                 33.93911  67.709953           0.0            0.0
# 1                 33.93911  67.709953           0.0            0.0
# 2                 33.93911  67.709953           0.0            0.0
# 3                 33.93911  67.709953           0.0            0.0
# 4                 33.93911  67.709953           0.0            0.0
# ...        ...         ...        ...           ...            ...
# 97642           -19.015438  29.154857        1756.9           44.0
# 97643           -19.015438  29.154857        1808.2           46.1
# 97644           -19.015438  29.154857        1861.7           47.3
# 97645           -19.015438  29.154857        1884.0           49.4
# 97646           -19.015438  29.154857        1931.7           53.5
#
#        New Deaths (n)  New Cases (n)  Multiple_Territories Month and Year Day  \
# 0                 NaN            NaN                 False       Jan 2020  22
# 1                 0.0            0.0                 False       Jan 2020  23
# 2                 0.0            0.0                 False       Jan 2020  24
# 3                 0.0            0.0                 False       Jan 2020  25
# 4                 0.0            0.0                 False       Jan 2020  26
# ...               ...            ...                   ...            ...  ..
# 97642            47.0         1112.0                 False       Jan 2021  14
# 97643            30.0          741.0                 False       Jan 2021  15
# 97644            17.0          772.0                 False       Jan 2021  16
# 97645            30.0          322.0                 False       Jan 2021  17
# 97646            60.0          689.0                 False       Jan 2021  18
#
#       ISO-3
# 0       AFG
# 1       AFG
# 2       AFG
# 3       AFG
# 4       AFG
# ...     ...
# 97642   ZWE
# 97643   ZWE
# 97644   ZWE
# 97645   ZWE
# 97646   ZWE
#
# [97647 rows x 17 columns]

# %%
# data['locations']['id' == 0]
# Out:
# {'id': 0,
#  'country': 'Afghanistan',
#  'country_code': 'AF',
#  'country_population': 37172386,
#  'province': '',
#  'last_updated': '2021-01-19T12:40:46.737392Z',
#  'coordinates': {'latitude': '33.93911', 'longitude': '67.709953'},
#  'latest': {'confirmed': 54062, 'deaths': 2343, 'recovered': 46359}}

# %%
for row in data['locations']:
    print(row)
# Out:
# {'id': 0, 'country': 'Afghanistan', 'country_code': 'AF', 'country_population': 37172386, 'province': '', 'last_updated': '2021-01-19T12:40:46.737392Z', 'coordinates': {'latitude': '33.93911', 'longitude': '67.709953'}, 'latest': {'confirmed': 54062, 'deaths': 2343, 'recovered': 46359}}
# {'id': 1, 'country': 'Albania', 'country_code': 'AL', 'country_population': 2866376, 'province': '', 'last_updated': '2021-01-19T12:40:46.883130Z', 'coordinates': {'latitude': '41.1533', 'longitude': '20.1683'}, 'latest': {'confirmed': 67982, 'deaths': 1281, 'recovered': 40870}}
# {'id': 2, 'country': 'Algeria', 'country_code': 'DZ', 'country_population': 42228429, 'province': '', 'last_updated': '2021-01-19T12:40:47.001421Z', 'coordinates': {'latitude': '28.0339', 'longitude': '1.6596'}, 'latest': {'confirmed': 104092, 'deaths': 2840, 'recovered': 70747}}
# {'id': 3, 'country': 'Andorra', 'country_code': 'AD', 'country_population': 77006, 'province': '', 'last_updated': '2021-01-19T12:40:47.072436Z', 'coordinates': {'latitude': '42.5063', 'longitude': '1.5218'}, 'latest': {'confirmed': 9083, 'deaths': 91, 'recovered': 8154}}
# {'id': 4, 'country': 'Angola', 'country_code': 'AO', 'country_population': 30809762, 'province': '', 'last_updated': '2021-01-19T12:40:47.143255Z', 'coordinates': {'latitude': '-11.2027', 'longitude': '17.8739'}, 'latest': {'confirmed': 18926, 'deaths': 439, 'recovered': 16677}}
# {'id': 5, 'country': 'Antigua and Barbuda', 'country_code': 'AG', 'country_population': 96286, 'province': '', 'last_updated': '2021-01-19T12:40:47.214053Z', 'coordinates': {'latitude': '17.0608', 'longitude': '-61.7964'}, 'latest': {'confirmed': 189, 'deaths': 6, 'recovered': 156}}
# {'id': 6, 'country': 'Argentina', 'country_code': 'AR', 'country_population': 44494502, 'province': '', 'last_updated': '2021-01-19T12:40:47.285289Z', 'coordinates': {'latitude': '-38.4161', 'longitude': '-63.6167'}, 'latest': {'confirmed': 1807428, 'deaths': 45832, 'recovered': 1594768}}
# {'id': 7, 'country': 'Armenia', 'country_code': 'AM', 'country_population': 2951776, 'province': '', 'last_updated': '2021-01-19T12:40:47.359787Z', 'coordinates': {'latitude': '40.0691', 'longitude': '45.0382'}, 'latest': {'confirmed': 164676, 'deaths': 2998, 'recovered': 153064}}
# {'id': 8, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Australian Capital Territory', 'last_updated': '2021-01-19T12:40:47.446815Z', 'coordinates': {'latitude': '-35.4735', 'longitude': '149.0124'}, 'latest': {'confirmed': 118, 'deaths': 3, 'recovered': 115}}
# {'id': 9, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'New South Wales', 'last_updated': '2021-01-19T12:40:47.533504Z', 'coordinates': {'latitude': '-33.8688', 'longitude': '151.2093'}, 'latest': {'confirmed': 5076, 'deaths': 54, 'recovered': 3233}}
# {'id': 10, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Northern Territory', 'last_updated': '2021-01-19T12:40:47.605186Z', 'coordinates': {'latitude': '-12.4634', 'longitude': '130.8456'}, 'latest': {'confirmed': 93, 'deaths': 0, 'recovered': 86}}
# {'id': 11, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Queensland', 'last_updated': '2021-01-19T12:40:47.677284Z', 'coordinates': {'latitude': '-27.4698', 'longitude': '153.0251'}, 'latest': {'confirmed': 1297, 'deaths': 6, 'recovered': 1255}}
# {'id': 12, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'South Australia', 'last_updated': '2021-01-19T12:40:47.757680Z', 'coordinates': {'latitude': '-34.9285', 'longitude': '138.6007'}, 'latest': {'confirmed': 593, 'deaths': 4, 'recovered': 578}}
# {'id': 13, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Tasmania', 'last_updated': '2021-01-19T12:40:47.861967Z', 'coordinates': {'latitude': '-42.8821', 'longitude': '147.3272'}, 'latest': {'confirmed': 234, 'deaths': 13, 'recovered': 221}}
# {'id': 14, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Victoria', 'last_updated': '2021-01-19T12:40:47.932450Z', 'coordinates': {'latitude': '-37.8136', 'longitude': '144.9631'}, 'latest': {'confirmed': 20432, 'deaths': 820, 'recovered': 19578}}
# {'id': 15, 'country': 'Australia', 'country_code': 'AU', 'country_population': 24992369, 'province': 'Western Australia', 'last_updated': '2021-01-19T12:40:48.000938Z', 'coordinates': {'latitude': '-31.9505', 'longitude': '115.8605'}, 'latest': {'confirmed': 888, 'deaths': 9, 'recovered': 865}}
# {'id': 16, 'country': 'Austria', 'country_code': 'AT', 'country_population': 8847037, 'province': '', 'last_updated': '2021-01-19T12:40:48.079724Z', 'coordinates': {'latitude': '47.5162', 'longitude': '14.5501'}, 'latest': {'confirmed': 394939, 'deaths': 7122, 'recovered': 370865}}
# {'id': 17, 'country': 'Azerbaijan', 'country_code': 'AZ', 'country_population': 9942334, 'province': '', 'last_updated': '2021-01-19T12:40:48.149773Z', 'coordinates': {'latitude': '40.1431', 'longitude': '47.5769'}, 'latest': {'confirmed': 227391, 'deaths': 3022, 'recovered': 215771}}
# {'id': 18, 'country': 'Bahamas', 'country_code': 'BS', 'country_population': 385640, 'province': '', 'last_updated': '2021-01-19T12:40:48.220959Z', 'coordinates': {'latitude': '25.025885', 'longitude': '-78.035889'}, 'latest': {'confirmed': 8067, 'deaths': 175, 'recovered': 6680}}
# {'id': 19, 'country': 'Bahrain', 'country_code': 'BH', 'country_population': 1569439, 'province': '', 'last_updated': '2021-01-19T12:40:48.290709Z', 'coordinates': {'latitude': '26.0275', 'longitude': '50.55'}, 'latest': {'confirmed': 97940, 'deaths': 360, 'recovered': 94646}}
# {'id': 20, 'country': 'Bangladesh', 'country_code': 'BD', 'country_population': 161356039, 'province': '', 'last_updated': '2021-01-19T12:40:48.365183Z', 'coordinates': {'latitude': '23.685', 'longitude': '90.3563'}, 'latest': {'confirmed': 528329, 'deaths': 7922, 'recovered': 473173}}
# {'id': 21, 'country': 'Barbados', 'country_code': 'BB', 'country_population': 286641, 'province': '', 'last_updated': '2021-01-19T12:40:48.434590Z', 'coordinates': {'latitude': '13.1939', 'longitude': '-59.5432'}, 'latest': {'confirmed': 1095, 'deaths': 7, 'recovered': 493}}
# {'id': 22, 'country': 'Belarus', 'country_code': 'BY', 'country_population': 9485386, 'province': '', 'last_updated': '2021-01-19T12:40:48.508925Z', 'coordinates': {'latitude': '53.7098', 'longitude': '27.9534'}, 'latest': {'confirmed': 227360, 'deaths': 1591, 'recovered': 210779}}
# {'id': 23, 'country': 'Belgium', 'country_code': 'BE', 'country_population': 11422068, 'province': '', 'last_updated': '2021-01-19T12:40:48.594691Z', 'coordinates': {'latitude': '50.8333', 'longitude': '4.469936'}, 'latest': {'confirmed': 679771, 'deaths': 20472, 'recovered': 0}}
# {'id': 24, 'country': 'Belize', 'country_code': 'BZ', 'country_population': 383071, 'province': '', 'last_updated': '2021-01-19T12:40:48.672273Z', 'coordinates': {'latitude': '17.1899', 'longitude': '-88.4976'}, 'latest': {'confirmed': 11592, 'deaths': 282, 'recovered': 10782}}
# {'id': 25, 'country': 'Benin', 'country_code': 'BJ', 'country_population': 11485048, 'province': '', 'last_updated': '2021-01-19T12:40:48.734977Z', 'coordinates': {'latitude': '9.3077', 'longitude': '2.3158'}, 'latest': {'confirmed': 3413, 'deaths': 46, 'recovered': 3245}}
# {'id': 26, 'country': 'Bhutan', 'country_code': 'BT', 'country_population': 754394, 'province': '', 'last_updated': '2021-01-19T12:40:48.807218Z', 'coordinates': {'latitude': '27.5142', 'longitude': '90.4336'}, 'latest': {'confirmed': 843, 'deaths': 1, 'recovered': 583}}
# {'id': 27, 'country': 'Bolivia', 'country_code': 'BO', 'country_population': 11353142, 'province': '', 'last_updated': '2021-01-19T12:40:48.884452Z', 'coordinates': {'latitude': '-16.2902', 'longitude': '-63.5887'}, 'latest': {'confirmed': 188733, 'deaths': 9680, 'recovered': 144227}}
# {'id': 28, 'country': 'Bosnia and Herzegovina', 'country_code': 'BA', 'country_population': 3323929, 'province': '', 'last_updated': '2021-01-19T12:40:48.970117Z', 'coordinates': {'latitude': '43.9159', 'longitude': '17.6791'}, 'latest': {'confirmed': 118083, 'deaths': 4486, 'recovered': 86505}}
# {'id': 29, 'country': 'Botswana', 'country_code': 'BW', 'country_population': 2254126, 'province': '', 'last_updated': '2021-01-19T12:40:49.045133Z', 'coordinates': {'latitude': '-22.3285', 'longitude': '24.6849'}, 'latest': {'confirmed': 18630, 'deaths': 88, 'recovered': 14624}}
# {'id': 30, 'country': 'Brazil', 'country_code': 'BR', 'country_population': 209469333, 'province': '', 'last_updated': '2021-01-19T12:40:49.117354Z', 'coordinates': {'latitude': '-14.235', 'longitude': '-51.9253'}, 'latest': {'confirmed': 8511770, 'deaths': 210299, 'recovered': 7560460}}
# {'id': 31, 'country': 'Brunei', 'country_code': 'BN', 'country_population': 428962, 'province': '', 'last_updated': '2021-01-19T12:40:49.191983Z', 'coordinates': {'latitude': '4.5353', 'longitude': '114.7277'}, 'latest': {'confirmed': 174, 'deaths': 3, 'recovered': 169}}
# {'id': 32, 'country': 'Bulgaria', 'country_code': 'BG', 'country_population': 7000039, 'province': '', 'last_updated': '2021-01-19T12:40:49.261505Z', 'coordinates': {'latitude': '42.7339', 'longitude': '25.4858'}, 'latest': {'confirmed': 212383, 'deaths': 8565, 'recovered': 164255}}
# {'id': 33, 'country': 'Burkina Faso', 'country_code': 'BF', 'country_population': 19751535, 'province': '', 'last_updated': '2021-01-19T12:40:49.330454Z', 'coordinates': {'latitude': '12.2383', 'longitude': '-1.5616'}, 'latest': {'confirmed': 9352, 'deaths': 105, 'recovered': 7448}}
# {'id': 34, 'country': 'Burma', 'country_code': 'MM', 'country_population': 53708395, 'province': '', 'last_updated': '2021-01-19T12:40:49.406403Z', 'coordinates': {'latitude': '21.9162', 'longitude': '95.956'}, 'latest': {'confirmed': 134795, 'deaths': 2973, 'recovered': 118200}}
# {'id': 35, 'country': 'Burundi', 'country_code': 'BI', 'country_population': 11175378, 'province': '', 'last_updated': '2021-01-19T12:40:49.480855Z', 'coordinates': {'latitude': '-3.3731', 'longitude': '29.9189'}, 'latest': {'confirmed': 1245, 'deaths': 2, 'recovered': 773}}
# {'id': 36, 'country': 'Cabo Verde', 'country_code': 'CV', 'country_population': 543767, 'province': '', 'last_updated': '2021-01-19T12:40:49.556478Z', 'coordinates': {'latitude': '16.5388', 'longitude': '-23.0418'}, 'latest': {'confirmed': 13046, 'deaths': 120, 'recovered': 12287}}
# {'id': 37, 'country': 'Cambodia', 'country_code': 'KH', 'country_population': 16249798, 'province': '', 'last_updated': '2021-01-19T12:40:49.630492Z', 'coordinates': {'latitude': '11.55', 'longitude': '104.9167'}, 'latest': {'confirmed': 441, 'deaths': 0, 'recovered': 386}}
# {'id': 38, 'country': 'Cameroon', 'country_code': 'CM', 'country_population': 25216237, 'province': '', 'last_updated': '2021-01-19T12:40:49.699841Z', 'coordinates': {'latitude': '3.848', 'longitude': '11.5021'}, 'latest': {'confirmed': 28010, 'deaths': 455, 'recovered': 26861}}
# {'id': 39, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Alberta', 'last_updated': '2021-01-19T12:40:49.769665Z', 'coordinates': {'latitude': '53.9333', 'longitude': '-116.5765'}, 'latest': {'confirmed': 117311, 'deaths': 1447, 'recovered': 0}}
# {'id': 40, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'British Columbia', 'last_updated': '2021-01-19T12:40:49.815736Z', 'coordinates': {'latitude': '53.7267', 'longitude': '-127.6476'}, 'latest': {'confirmed': 61447, 'deaths': 1078, 'recovered': 0}}
# {'id': 41, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Diamond Princess', 'last_updated': '2021-01-19T12:40:49.863266Z', 'coordinates': {'latitude': '0.0', 'longitude': '0.0'}, 'latest': {'confirmed': 0, 'deaths': 1, 'recovered': 0}}
# {'id': 42, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Grand Princess', 'last_updated': '2021-01-19T12:40:49.911926Z', 'coordinates': {'latitude': '0.0', 'longitude': '0.0'}, 'latest': {'confirmed': 13, 'deaths': 0, 'recovered': 0}}
# {'id': 43, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Manitoba', 'last_updated': '2021-01-19T12:40:49.967905Z', 'coordinates': {'latitude': '53.7609', 'longitude': '-98.8139'}, 'latest': {'confirmed': 27629, 'deaths': 773, 'recovered': 0}}
# {'id': 44, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'New Brunswick', 'last_updated': '2021-01-19T12:40:50.031151Z', 'coordinates': {'latitude': '46.5653', 'longitude': '-66.4619'}, 'latest': {'confirmed': 973, 'deaths': 12, 'recovered': 0}}
# {'id': 45, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Newfoundland and Labrador', 'last_updated': '2021-01-19T12:40:50.113007Z', 'coordinates': {'latitude': '53.1355', 'longitude': '-57.6604'}, 'latest': {'confirmed': 396, 'deaths': 4, 'recovered': 0}}
# {'id': 46, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Northwest Territories', 'last_updated': '2021-01-19T12:40:50.199284Z', 'coordinates': {'latitude': '64.8255', 'longitude': '-124.8457'}, 'latest': {'confirmed': 25, 'deaths': 0, 'recovered': 0}}
# {'id': 47, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Nova Scotia', 'last_updated': '2021-01-19T12:40:50.316712Z', 'coordinates': {'latitude': '44.682', 'longitude': '-63.7443'}, 'latest': {'confirmed': 1557, 'deaths': 65, 'recovered': 0}}
# {'id': 48, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Nunavut', 'last_updated': '2021-01-19T12:40:50.363357Z', 'coordinates': {'latitude': '70.2998', 'longitude': '-83.1076'}, 'latest': {'confirmed': 266, 'deaths': 1, 'recovered': 0}}
# {'id': 49, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Ontario', 'last_updated': '2021-01-19T12:40:50.410864Z', 'coordinates': {'latitude': '51.2538', 'longitude': '-85.3232'}, 'latest': {'confirmed': 244883, 'deaths': 5442, 'recovered': 0}}
# {'id': 50, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Prince Edward Island', 'last_updated': '2021-01-19T12:40:50.457694Z', 'coordinates': {'latitude': '46.5107', 'longitude': '-63.4168'}, 'latest': {'confirmed': 108, 'deaths': 0, 'recovered': 0}}
# {'id': 51, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Quebec', 'last_updated': '2021-01-19T12:40:50.584815Z', 'coordinates': {'latitude': '52.9399', 'longitude': '-73.5491'}, 'latest': {'confirmed': 244348, 'deaths': 9087, 'recovered': 0}}
# {'id': 52, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Repatriated Travellers', 'last_updated': '2021-01-19T12:40:50.778712Z', 'coordinates': {'latitude': '', 'longitude': ''}, 'latest': {'confirmed': 13, 'deaths': 0, 'recovered': 0}}
# {'id': 53, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Saskatchewan', 'last_updated': '2021-01-19T12:40:50.951363Z', 'coordinates': {'latitude': '52.9399', 'longitude': '-106.4509'}, 'latest': {'confirmed': 20562, 'deaths': 219, 'recovered': 0}}
# {'id': 54, 'country': 'Canada', 'country_code': 'CA', 'country_population': 37058856, 'province': 'Yukon', 'last_updated': '2021-01-19T12:40:50.999844Z', 'coordinates': {'latitude': '64.2823', 'longitude': '-135.0'}, 'latest': {'confirmed': 70, 'deaths': 1, 'recovered': 0}}
# {'id': 55, 'country': 'Central African Republic', 'country_code': 'CF', 'country_population': 4666377, 'province': '', 'last_updated': '2021-01-19T12:40:51.078336Z', 'coordinates': {'latitude': '6.6111', 'longitude': '20.9394'}, 'latest': {'confirmed': 4973, 'deaths': 63, 'recovered': 0}}
# {'id': 56, 'country': 'Chad', 'country_code': 'TD', 'country_population': 15477751, 'province': '', 'last_updated': '2021-01-19T12:40:51.240021Z', 'coordinates': {'latitude': '15.4542', 'longitude': '18.7322'}, 'latest': {'confirmed': 2919, 'deaths': 113, 'recovered': 0}}
# {'id': 57, 'country': 'Chile', 'country_code': 'CL', 'country_population': 18729160, 'province': '', 'last_updated': '2021-01-19T12:40:51.316129Z', 'coordinates': {'latitude': '-35.6751', 'longitude': '-71.543'}, 'latest': {'confirmed': 673750, 'deaths': 17547, 'recovered': 0}}
# {'id': 58, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Anhui', 'last_updated': '2021-01-19T12:40:51.435538Z', 'coordinates': {'latitude': '31.8257', 'longitude': '117.2264'}, 'latest': {'confirmed': 993, 'deaths': 6, 'recovered': 0}}
# {'id': 59, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Beijing', 'last_updated': '2021-01-19T12:40:51.483097Z', 'coordinates': {'latitude': '40.1824', 'longitude': '116.4142'}, 'latest': {'confirmed': 1007, 'deaths': 9, 'recovered': 0}}
# {'id': 60, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Chongqing', 'last_updated': '2021-01-19T12:40:51.567894Z', 'coordinates': {'latitude': '30.0572', 'longitude': '107.874'}, 'latest': {'confirmed': 591, 'deaths': 6, 'recovered': 0}}
# {'id': 61, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Fujian', 'last_updated': '2021-01-19T12:40:51.618433Z', 'coordinates': {'latitude': '26.0789', 'longitude': '117.9874'}, 'latest': {'confirmed': 532, 'deaths': 1, 'recovered': 0}}
# {'id': 62, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Gansu', 'last_updated': '2021-01-19T12:40:51.664169Z', 'coordinates': {'latitude': '35.7518', 'longitude': '104.2861'}, 'latest': {'confirmed': 182, 'deaths': 2, 'recovered': 0}}
# {'id': 63, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Guangdong', 'last_updated': '2021-01-19T12:40:51.710191Z', 'coordinates': {'latitude': '23.3417', 'longitude': '113.4244'}, 'latest': {'confirmed': 2090, 'deaths': 8, 'recovered': 0}}
# {'id': 64, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Guangxi', 'last_updated': '2021-01-19T12:40:51.805114Z', 'coordinates': {'latitude': '23.8298', 'longitude': '108.7881'}, 'latest': {'confirmed': 266, 'deaths': 2, 'recovered': 0}}
# {'id': 65, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Guizhou', 'last_updated': '2021-01-19T12:40:51.876244Z', 'coordinates': {'latitude': '26.8154', 'longitude': '106.8748'}, 'latest': {'confirmed': 147, 'deaths': 2, 'recovered': 0}}
# {'id': 66, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Hainan', 'last_updated': '2021-01-19T12:40:51.937261Z', 'coordinates': {'latitude': '19.1959', 'longitude': '109.7453'}, 'latest': {'confirmed': 171, 'deaths': 6, 'recovered': 0}}
# {'id': 67, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Hebei', 'last_updated': '2021-01-19T12:40:51.984076Z', 'coordinates': {'latitude': '39.549', 'longitude': '116.1306'}, 'latest': {'confirmed': 1192, 'deaths': 7, 'recovered': 0}}
# {'id': 68, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Heilongjiang', 'last_updated': '2021-01-19T12:40:52.031878Z', 'coordinates': {'latitude': '47.862', 'longitude': '127.7615'}, 'latest': {'confirmed': 1143, 'deaths': 13, 'recovered': 0}}
# {'id': 69, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Henan', 'last_updated': '2021-01-19T12:40:52.085290Z', 'coordinates': {'latitude': '37.8957', 'longitude': '114.9042'}, 'latest': {'confirmed': 1303, 'deaths': 22, 'recovered': 0}}
# {'id': 70, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Hong Kong', 'last_updated': '2021-01-19T12:40:52.131884Z', 'coordinates': {'latitude': '22.3', 'longitude': '114.2'}, 'latest': {'confirmed': 9664, 'deaths': 163, 'recovered': 0}}
# {'id': 71, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Hubei', 'last_updated': '2021-01-19T12:40:52.187964Z', 'coordinates': {'latitude': '30.9756', 'longitude': '112.2707'}, 'latest': {'confirmed': 68149, 'deaths': 4512, 'recovered': 0}}
# {'id': 72, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Hunan', 'last_updated': '2021-01-19T12:40:52.264806Z', 'coordinates': {'latitude': '27.6104', 'longitude': '111.7088'}, 'latest': {'confirmed': 1026, 'deaths': 4, 'recovered': 0}}
# {'id': 73, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Inner Mongolia', 'last_updated': '2021-01-19T12:40:52.310207Z', 'coordinates': {'latitude': '44.0935', 'longitude': '113.9448'}, 'latest': {'confirmed': 366, 'deaths': 1, 'recovered': 0}}
# {'id': 74, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Jiangsu', 'last_updated': '2021-01-19T12:40:52.355525Z', 'coordinates': {'latitude': '32.9711', 'longitude': '119.455'}, 'latest': {'confirmed': 688, 'deaths': 0, 'recovered': 0}}
# {'id': 75, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Jiangxi', 'last_updated': '2021-01-19T12:40:52.419922Z', 'coordinates': {'latitude': '27.614', 'longitude': '115.7221'}, 'latest': {'confirmed': 935, 'deaths': 1, 'recovered': 0}}
# {'id': 76, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Jilin', 'last_updated': '2021-01-19T12:40:52.474363Z', 'coordinates': {'latitude': '43.6661', 'longitude': '126.1923'}, 'latest': {'confirmed': 240, 'deaths': 2, 'recovered': 0}}
# {'id': 77, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Liaoning', 'last_updated': '2021-01-19T12:40:52.536101Z', 'coordinates': {'latitude': '41.2956', 'longitude': '122.6085'}, 'latest': {'confirmed': 396, 'deaths': 2, 'recovered': 0}}
# {'id': 78, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Macau', 'last_updated': '2021-01-19T12:40:52.590996Z', 'coordinates': {'latitude': '22.1667', 'longitude': '113.55'}, 'latest': {'confirmed': 46, 'deaths': 0, 'recovered': 0}}
# {'id': 79, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Ningxia', 'last_updated': '2021-01-19T12:40:52.635829Z', 'coordinates': {'latitude': '37.2692', 'longitude': '106.1655'}, 'latest': {'confirmed': 75, 'deaths': 0, 'recovered': 0}}
# {'id': 80, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Qinghai', 'last_updated': '2021-01-19T12:40:52.683954Z', 'coordinates': {'latitude': '35.7452', 'longitude': '95.9956'}, 'latest': {'confirmed': 18, 'deaths': 0, 'recovered': 0}}
# {'id': 81, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Shaanxi', 'last_updated': '2021-01-19T12:40:52.730168Z', 'coordinates': {'latitude': '35.1917', 'longitude': '108.8701'}, 'latest': {'confirmed': 531, 'deaths': 3, 'recovered': 0}}
# {'id': 82, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Shandong', 'last_updated': '2021-01-19T12:40:52.776529Z', 'coordinates': {'latitude': '36.3427', 'longitude': '118.1498'}, 'latest': {'confirmed': 865, 'deaths': 7, 'recovered': 0}}
# {'id': 83, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Shanghai', 'last_updated': '2021-01-19T12:40:52.842504Z', 'coordinates': {'latitude': '31.202', 'longitude': '121.4491'}, 'latest': {'confirmed': 1602, 'deaths': 7, 'recovered': 0}}
# {'id': 84, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Shanxi', 'last_updated': '2021-01-19T12:40:52.888028Z', 'coordinates': {'latitude': '37.5777', 'longitude': '112.2922'}, 'latest': {'confirmed': 228, 'deaths': 0, 'recovered': 0}}
# {'id': 85, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Sichuan', 'last_updated': '2021-01-19T12:40:52.935215Z', 'coordinates': {'latitude': '30.6171', 'longitude': '102.7103'}, 'latest': {'confirmed': 863, 'deaths': 3, 'recovered': 0}}
# {'id': 86, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Tianjin', 'last_updated': '2021-01-19T12:40:53.004548Z', 'coordinates': {'latitude': '39.3054', 'longitude': '117.323'}, 'latest': {'confirmed': 329, 'deaths': 3, 'recovered': 0}}
# {'id': 87, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Tibet', 'last_updated': '2021-01-19T12:40:53.191448Z', 'coordinates': {'latitude': '31.6927', 'longitude': '88.0924'}, 'latest': {'confirmed': 1, 'deaths': 0, 'recovered': 0}}
# {'id': 88, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Xinjiang', 'last_updated': '2021-01-19T12:40:53.337843Z', 'coordinates': {'latitude': '41.1129', 'longitude': '85.2401'}, 'latest': {'confirmed': 980, 'deaths': 3, 'recovered': 0}}
# {'id': 89, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Yunnan', 'last_updated': '2021-01-19T12:40:53.379847Z', 'coordinates': {'latitude': '24.974', 'longitude': '101.487'}, 'latest': {'confirmed': 231, 'deaths': 2, 'recovered': 0}}
# {'id': 90, 'country': 'China', 'country_code': 'CN', 'country_population': 1392730000, 'province': 'Zhejiang', 'last_updated': '2021-01-19T12:40:53.429678Z', 'coordinates': {'latitude': '29.1832', 'longitude': '120.0934'}, 'latest': {'confirmed': 1314, 'deaths': 1, 'recovered': 0}}
# {'id': 91, 'country': 'Colombia', 'country_code': 'CO', 'country_population': 49648685, 'province': '', 'last_updated': '2021-01-19T12:40:53.513879Z', 'coordinates': {'latitude': '4.5709', 'longitude': '-74.2973'}, 'latest': {'confirmed': 1923132, 'deaths': 49004, 'recovered': 0}}
# {'id': 92, 'country': 'Comoros', 'country_code': 'KM', 'country_population': 832322, 'province': '', 'last_updated': '2021-01-19T12:40:53.657984Z', 'coordinates': {'latitude': '-11.6455', 'longitude': '43.3333'}, 'latest': {'confirmed': 1769, 'deaths': 49, 'recovered': 0}}
# {'id': 93, 'country': 'Congo (Brazzaville)', 'country_code': 'CG', 'country_population': 5244363, 'province': '', 'last_updated': '2021-01-19T12:40:53.711643Z', 'coordinates': {'latitude': '-0.228', 'longitude': '15.8277'}, 'latest': {'confirmed': 7709, 'deaths': 114, 'recovered': 0}}
# {'id': 94, 'country': 'Congo (Kinshasa)', 'country_code': 'CD', 'country_population': 84068091, 'province': '', 'last_updated': '2021-01-19T12:40:53.769926Z', 'coordinates': {'latitude': '-4.0383', 'longitude': '21.7587'}, 'latest': {'confirmed': 21060, 'deaths': 634, 'recovered': 0}}
# {'id': 95, 'country': 'Costa Rica', 'country_code': 'CR', 'country_population': 4999441, 'province': '', 'last_updated': '2021-01-19T12:40:53.820685Z', 'coordinates': {'latitude': '9.7489', 'longitude': '-83.7534'}, 'latest': {'confirmed': 186016, 'deaths': 2458, 'recovered': 0}}
# {'id': 96, 'country': "Cote d'Ivoire", 'country_code': 'CI', 'country_population': 25069229, 'province': '', 'last_updated': '2021-01-19T12:40:53.867944Z', 'coordinates': {'latitude': '7.54', 'longitude': '-5.5471'}, 'latest': {'confirmed': 25304, 'deaths': 142, 'recovered': 0}}
# {'id': 97, 'country': 'Croatia', 'country_code': 'HR', 'country_population': 4089400, 'province': '', 'last_updated': '2021-01-19T12:40:53.922626Z', 'coordinates': {'latitude': '45.1', 'longitude': '15.2'}, 'latest': {'confirmed': 225128, 'deaths': 4655, 'recovered': 0}}
# {'id': 98, 'country': 'Cuba', 'country_code': 'CU', 'country_population': 11338138, 'province': '', 'last_updated': '2021-01-19T12:40:53.980476Z', 'coordinates': {'latitude': '21.521757', 'longitude': '-77.781167'}, 'latest': {'confirmed': 18443, 'deaths': 173, 'recovered': 0}}
# {'id': 99, 'country': 'Cyprus', 'country_code': 'CY', 'country_population': 1189265, 'province': '', 'last_updated': '2021-01-19T12:40:54.027964Z', 'coordinates': {'latitude': '35.1264', 'longitude': '33.4299'}, 'latest': {'confirmed': 29130, 'deaths': 175, 'recovered': 0}}
# {'id': 100, 'country': 'Czechia', 'country_code': 'CZ', 'country_population': 10625695, 'province': '', 'last_updated': '2021-01-19T12:40:54.087381Z', 'coordinates': {'latitude': '49.8175', 'longitude': '15.473'}, 'latest': {'confirmed': 891852, 'deaths': 14449, 'recovered': 0}}
# {'id': 101, 'country': 'Denmark', 'country_code': 'DK', 'country_population': 5797446, 'province': 'Faroe Islands', 'last_updated': '2021-01-19T12:40:54.180603Z', 'coordinates': {'latitude': '61.8926', 'longitude': '-6.9118'}, 'latest': {'confirmed': 649, 'deaths': 1, 'recovered': 0}}
# {'id': 102, 'country': 'Denmark', 'country_code': 'DK', 'country_population': 5797446, 'province': 'Greenland', 'last_updated': '2021-01-19T12:40:54.255170Z', 'coordinates': {'latitude': '71.7069', 'longitude': '-42.6043'}, 'latest': {'confirmed': 30, 'deaths': 0, 'recovered': 0}}
# {'id': 103, 'country': 'Denmark', 'country_code': 'DK', 'country_population': 5797446, 'province': '', 'last_updated': '2021-01-19T12:40:54.305328Z', 'coordinates': {'latitude': '56.2639', 'longitude': '9.5018'}, 'latest': {'confirmed': 189895, 'deaths': 1805, 'recovered': 0}}
# {'id': 104, 'country': 'Diamond Princess', 'country_code': 'XX', 'country_population': None, 'province': '', 'last_updated': '2021-01-19T12:40:54.351421Z', 'coordinates': {'latitude': '0.0', 'longitude': '0.0'}, 'latest': {'confirmed': 712, 'deaths': 13, 'recovered': 0}}
# {'id': 105, 'country': 'Djibouti', 'country_code': 'DJ', 'country_population': 958920, 'province': '', 'last_updated': '2021-01-19T12:40:54.396472Z', 'coordinates': {'latitude': '11.8251', 'longitude': '42.5903'}, 'latest': {'confirmed': 5905, 'deaths': 61, 'recovered': 0}}
# {'id': 106, 'country': 'Dominica', 'country_code': 'DM', 'country_population': 71625, 'province': '', 'last_updated': '2021-01-19T12:40:54.442639Z', 'coordinates': {'latitude': '15.415', 'longitude': '-61.371'}, 'latest': {'confirmed': 110, 'deaths': 0, 'recovered': 0}}
# {'id': 107, 'country': 'Dominican Republic', 'country_code': 'DO', 'country_population': 10627165, 'province': '', 'last_updated': '2021-01-19T12:40:54.489197Z', 'coordinates': {'latitude': '18.7357', 'longitude': '-70.1627'}, 'latest': {'confirmed': 194966, 'deaths': 2448, 'recovered': 0}}
# {'id': 108, 'country': 'Ecuador', 'country_code': 'EC', 'country_population': 17084357, 'province': '', 'last_updated': '2021-01-19T12:40:54.535176Z', 'coordinates': {'latitude': '-1.8312', 'longitude': '-78.1834'}, 'latest': {'confirmed': 231644, 'deaths': 14322, 'recovered': 0}}
# {'id': 109, 'country': 'Egypt', 'country_code': 'EG', 'country_population': 98423595, 'province': '', 'last_updated': '2021-01-19T12:40:54.580649Z', 'coordinates': {'latitude': '26.820553', 'longitude': '30.802498'}, 'latest': {'confirmed': 157275, 'deaths': 8638, 'recovered': 0}}
# {'id': 110, 'country': 'El Salvador', 'country_code': 'SV', 'country_population': 6420744, 'province': '', 'last_updated': '2021-01-19T12:40:54.626519Z', 'coordinates': {'latitude': '13.7942', 'longitude': '-88.8965'}, 'latest': {'confirmed': 51437, 'deaths': 1498, 'recovered': 0}}
# {'id': 111, 'country': 'Equatorial Guinea', 'country_code': 'GQ', 'country_population': 1308974, 'province': '', 'last_updated': '2021-01-19T12:40:54.672477Z', 'coordinates': {'latitude': '1.6508', 'longitude': '10.2679'}, 'latest': {'confirmed': 5365, 'deaths': 86, 'recovered': 0}}
# {'id': 112, 'country': 'Eritrea', 'country_code': 'ER', 'country_population': None, 'province': '', 'last_updated': '2021-01-19T12:40:54.717919Z', 'coordinates': {'latitude': '15.1794', 'longitude': '39.7823'}, 'latest': {'confirmed': 1877, 'deaths': 6, 'recovered': 0}}
# {'id': 113, 'country': 'Estonia', 'country_code': 'EE', 'country_population': 1320884, 'province': '', 'last_updated': '2021-01-19T12:40:54.779965Z', 'coordinates': {'latitude': '58.5953', 'longitude': '25.0136'}, 'latest': {'confirmed': 37344, 'deaths': 333, 'recovered': 0}}
# {'id': 114, 'country': 'Eswatini', 'country_code': 'SZ', 'country_population': 1136191, 'province': '', 'last_updated': '2021-01-19T12:40:54.825166Z', 'coordinates': {'latitude': '-26.5225', 'longitude': '31.4659'}, 'latest': {'confirmed': 13187, 'deaths': 384, 'recovered': 0}}
# {'id': 115, 'country': 'Ethiopia', 'country_code': 'ET', 'country_population': 109224559, 'province': '', 'last_updated': '2021-01-19T12:40:54.870422Z', 'coordinates': {'latitude': '9.145', 'longitude': '40.4897'}, 'latest': {'confirmed': 131546, 'deaths': 2033, 'recovered': 0}}
# {'id': 116, 'country': 'Fiji', 'country_code': 'FJ', 'country_population': 883483, 'province': '', 'last_updated': '2021-01-19T12:40:54.919612Z', 'coordinates': {'latitude': '-17.7134', 'longitude': '178.065'}, 'latest': {'confirmed': 55, 'deaths': 2, 'recovered': 0}}
# {'id': 117, 'country': 'Finland', 'country_code': 'FI', 'country_population': 5518050, 'province': '', 'last_updated': '2021-01-19T12:40:54.965777Z', 'coordinates': {'latitude': '61.92411', 'longitude': '25.748151'}, 'latest': {'confirmed': 40505, 'deaths': 618, 'recovered': 0}}
# {'id': 118, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'French Guiana', 'last_updated': '2021-01-19T12:40:55.011401Z', 'coordinates': {'latitude': '3.9339', 'longitude': '-53.1258'}, 'latest': {'confirmed': 14975, 'deaths': 75, 'recovered': 0}}
# {'id': 119, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'French Polynesia', 'last_updated': '2021-01-19T12:40:55.058157Z', 'coordinates': {'latitude': '-17.6797', 'longitude': '149.4068'}, 'latest': {'confirmed': 17697, 'deaths': 127, 'recovered': 0}}
# {'id': 120, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Guadeloupe', 'last_updated': '2021-01-19T12:40:55.103609Z', 'coordinates': {'latitude': '16.265', 'longitude': '-61.551'}, 'latest': {'confirmed': 8834, 'deaths': 156, 'recovered': 0}}
# {'id': 121, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Martinique', 'last_updated': '2021-01-19T12:40:55.149111Z', 'coordinates': {'latitude': '14.6415', 'longitude': '-61.0242'}, 'latest': {'confirmed': 6227, 'deaths': 43, 'recovered': 0}}
# {'id': 122, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Mayotte', 'last_updated': '2021-01-19T12:40:55.195825Z', 'coordinates': {'latitude': '-12.8275', 'longitude': '45.166244'}, 'latest': {'confirmed': 6611, 'deaths': 58, 'recovered': 0}}
# {'id': 123, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'New Caledonia', 'last_updated': '2021-01-19T12:40:55.241440Z', 'coordinates': {'latitude': '-20.904305', 'longitude': '165.618042'}, 'latest': {'confirmed': 44, 'deaths': 0, 'recovered': 0}}
# {'id': 124, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Reunion', 'last_updated': '2021-01-19T12:40:55.307381Z', 'coordinates': {'latitude': '-21.1151', 'longitude': '55.5364'}, 'latest': {'confirmed': 9443, 'deaths': 45, 'recovered': 0}}
# {'id': 125, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Saint Barthelemy', 'last_updated': '2021-01-19T12:40:55.357956Z', 'coordinates': {'latitude': '17.9', 'longitude': '-62.8333'}, 'latest': {'confirmed': 251, 'deaths': 1, 'recovered': 0}}
# {'id': 126, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Saint Pierre and Miquelon', 'last_updated': '2021-01-19T12:40:55.402658Z', 'coordinates': {'latitude': '46.8852', 'longitude': '-56.3159'}, 'latest': {'confirmed': 16, 'deaths': 0, 'recovered': 0}}
# {'id': 127, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'St Martin', 'last_updated': '2021-01-19T12:40:55.448115Z', 'coordinates': {'latitude': '18.0708', 'longitude': '-63.0501'}, 'latest': {'confirmed': 1076, 'deaths': 12, 'recovered': 0}}
# {'id': 128, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': 'Wallis and Futuna', 'last_updated': '2021-01-19T12:40:55.494787Z', 'coordinates': {'latitude': '-14.2938', 'longitude': '-178.1165'}, 'latest': {'confirmed': 4, 'deaths': 0, 'recovered': 0}}
# {'id': 129, 'country': 'France', 'country_code': 'FR', 'country_population': 66987244, 'province': '', 'last_updated': '2021-01-19T12:40:55.545795Z', 'coordinates': {'latitude': '46.2276', 'longitude': '2.2137'}, 'latest': {'confirmed': 2907711, 'deaths': 70309, 'recovered': 0}}
# {'id': 130, 'country': 'Gabon', 'country_code': 'GA', 'country_population': 2119275, 'province': '', 'last_updated': '2021-01-19T12:40:55.605012Z', 'coordinates': {'latitude': '-0.8037', 'longitude': '11.6094'}, 'latest': {'confirmed': 10019, 'deaths': 66, 'recovered': 0}}
# {'id': 131, 'country': 'Gambia', 'country_code': 'GM', 'country_population': 2280102, 'province': '', 'last_updated': '2021-01-19T12:40:55.651695Z', 'coordinates': {'latitude': '13.4432', 'longitude': '-15.3101'}, 'latest': {'confirmed': 3933, 'deaths': 128, 'recovered': 0}}
# {'id': 132, 'country': 'Georgia', 'country_code': 'GE', 'country_population': 3731000, 'province': '', 'last_updated': '2021-01-19T12:40:55.702571Z', 'coordinates': {'latitude': '42.3154', 'longitude': '43.3569'}, 'latest': {'confirmed': 247915, 'deaths': 2958, 'recovered': 0}}
# {'id': 133, 'country': 'Germany', 'country_code': 'DE', 'country_population': 82927922, 'province': '', 'last_updated': '2021-01-19T12:40:55.757962Z', 'coordinates': {'latitude': '51.165691', 'longitude': '10.451526'}, 'latest': {'confirmed': 2059382, 'deaths': 47263, 'recovered': 0}}
# {'id': 134, 'country': 'Ghana', 'country_code': 'GH', 'country_population': 29767108, 'province': '', 'last_updated': '2021-01-19T12:40:55.803038Z', 'coordinates': {'latitude': '7.9465', 'longitude': '-1.0232'}, 'latest': {'confirmed': 58065, 'deaths': 352, 'recovered': 0}}
# {'id': 135, 'country': 'Greece', 'country_code': 'GR', 'country_population': 10727668, 'province': '', 'last_updated': '2021-01-19T12:40:55.854116Z', 'coordinates': {'latitude': '39.0742', 'longitude': '21.8243'}, 'latest': {'confirmed': 148925, 'deaths': 5488, 'recovered': 0}}
# {'id': 136, 'country': 'Grenada', 'country_code': 'GD', 'country_population': 111454, 'province': '', 'last_updated': '2021-01-19T12:40:55.900036Z', 'coordinates': {'latitude': '12.1165', 'longitude': '-61.679'}, 'latest': {'confirmed': 139, 'deaths': 1, 'recovered': 0}}
# {'id': 137, 'country': 'Guatemala', 'country_code': 'GT', 'country_population': 17247807, 'province': '', 'last_updated': '2021-01-19T12:40:55.946682Z', 'coordinates': {'latitude': '15.7835', 'longitude': '-90.2308'}, 'latest': {'confirmed': 149146, 'deaths': 5278, 'recovered': 0}}
# {'id': 138, 'country': 'Guinea', 'country_code': 'GN', 'country_population': 12414318, 'province': '', 'last_updated': '2021-01-19T12:40:56.008448Z', 'coordinates': {'latitude': '9.9456', 'longitude': '-9.6966'}, 'latest': {'confirmed': 14165, 'deaths': 81, 'recovered': 0}}
# {'id': 139, 'country': 'Guinea-Bissau', 'country_code': 'GW', 'country_population': 1874309, 'province': '', 'last_updated': '2021-01-19T12:40:56.058881Z', 'coordinates': {'latitude': '11.8037', 'longitude': '-15.1804'}, 'latest': {'confirmed': 2509, 'deaths': 45, 'recovered': 0}}
# {'id': 140, 'country': 'Guyana', 'country_code': 'GY', 'country_population': 779004, 'province': '', 'last_updated': '2021-01-19T12:40:56.104215Z', 'coordinates': {'latitude': '4.860416', 'longitude': '-58.93018'}, 'latest': {'confirmed': 6931, 'deaths': 170, 'recovered': 0}}
# {'id': 141, 'country': 'Haiti', 'country_code': 'HT', 'country_population': 11123176, 'province': '', 'last_updated': '2021-01-19T12:40:56.161159Z', 'coordinates': {'latitude': '18.9712', 'longitude': '-72.2852'}, 'latest': {'confirmed': 10907, 'deaths': 240, 'recovered': 0}}
# {'id': 142, 'country': 'Holy See', 'country_code': 'VA', 'country_population': 921, 'province': '', 'last_updated': '2021-01-19T12:40:56.206536Z', 'coordinates': {'latitude': '41.9029', 'longitude': '12.4534'}, 'latest': {'confirmed': 27, 'deaths': 0, 'recovered': 0}}
# {'id': 143, 'country': 'Honduras', 'country_code': 'HN', 'country_population': 9587522, 'province': '', 'last_updated': '2021-01-19T12:40:56.253515Z', 'coordinates': {'latitude': '15.2', 'longitude': '-86.2419'}, 'latest': {'confirmed': 134938, 'deaths': 3368, 'recovered': 0}}
# {'id': 144, 'country': 'Hungary', 'country_code': 'HU', 'country_population': 9768785, 'province': '', 'last_updated': '2021-01-19T12:40:56.299152Z', 'coordinates': {'latitude': '47.1625', 'longitude': '19.5033'}, 'latest': {'confirmed': 352703, 'deaths': 11409, 'recovered': 0}}
# {'id': 145, 'country': 'Iceland', 'country_code': 'IS', 'country_population': 353574, 'province': '', 'last_updated': '2021-01-19T12:40:56.345100Z', 'coordinates': {'latitude': '64.9631', 'longitude': '-19.0208'}, 'latest': {'confirmed': 5970, 'deaths': 29, 'recovered': 0}}
# {'id': 146, 'country': 'India', 'country_code': 'IN', 'country_population': 1352617328, 'province': '', 'last_updated': '2021-01-19T12:40:56.390987Z', 'coordinates': {'latitude': '20.593684', 'longitude': '78.96288'}, 'latest': {'confirmed': 10581823, 'deaths': 152556, 'recovered': 0}}
# {'id': 147, 'country': 'Indonesia', 'country_code': 'ID', 'country_population': 267663435, 'province': '', 'last_updated': '2021-01-19T12:40:56.435839Z', 'coordinates': {'latitude': '-0.7893', 'longitude': '113.9213'}, 'latest': {'confirmed': 917015, 'deaths': 26282, 'recovered': 0}}
# {'id': 148, 'country': 'Iran', 'country_code': 'IR', 'country_population': 81800269, 'province': '', 'last_updated': '2021-01-19T12:40:56.480837Z', 'coordinates': {'latitude': '32.427908', 'longitude': '53.688046'}, 'latest': {'confirmed': 1336217, 'deaths': 56886, 'recovered': 0}}
# {'id': 149, 'country': 'Iraq', 'country_code': 'IQ', 'country_population': 38433600, 'province': '', 'last_updated': '2021-01-19T12:40:56.523190Z', 'coordinates': {'latitude': '33.223191', 'longitude': '43.679291'}, 'latest': {'confirmed': 609029, 'deaths': 12953, 'recovered': 0}}
# {'id': 150, 'country': 'Ireland', 'country_code': 'IE', 'country_population': 4853506, 'province': '', 'last_updated': '2021-01-19T12:40:56.571569Z', 'coordinates': {'latitude': '53.1424', 'longitude': '-7.6921'}, 'latest': {'confirmed': 174843, 'deaths': 2616, 'recovered': 0}}
# {'id': 151, 'country': 'Israel', 'country_code': 'IL', 'country_population': 8883800, 'province': '', 'last_updated': '2021-01-19T12:40:56.670671Z', 'coordinates': {'latitude': '31.046051', 'longitude': '34.851612'}, 'latest': {'confirmed': 558249, 'deaths': 4044, 'recovered': 0}}
# {'id': 152, 'country': 'Italy', 'country_code': 'IT', 'country_population': 60431283, 'province': '', 'last_updated': '2021-01-19T12:40:56.807919Z', 'coordinates': {'latitude': '41.87194', 'longitude': '12.56738'}, 'latest': {'confirmed': 2390102, 'deaths': 82554, 'recovered': 0}}
# {'id': 153, 'country': 'Jamaica', 'country_code': 'JM', 'country_population': 2934855, 'province': '', 'last_updated': '2021-01-19T12:40:57.033263Z', 'coordinates': {'latitude': '18.1096', 'longitude': '-77.2975'}, 'latest': {'confirmed': 14274, 'deaths': 326, 'recovered': 0}}
# {'id': 154, 'country': 'Japan', 'country_code': 'JP', 'country_population': 126529100, 'province': '', 'last_updated': '2021-01-19T12:40:57.234363Z', 'coordinates': {'latitude': '36.204824', 'longitude': '138.252924'}, 'latest': {'confirmed': 335605, 'deaths': 4366, 'recovered': 0}}
# {'id': 155, 'country': 'Jordan', 'country_code': 'JO', 'country_population': 9956011, 'province': '', 'last_updated': '2021-01-19T12:40:57.392460Z', 'coordinates': {'latitude': '31.24', 'longitude': '36.51'}, 'latest': {'confirmed': 315544, 'deaths': 4153, 'recovered': 0}}
# {'id': 156, 'country': 'Kazakhstan', 'country_code': 'KZ', 'country_population': 18276499, 'province': '', 'last_updated': '2021-01-19T12:40:57.441682Z', 'coordinates': {'latitude': '48.0196', 'longitude': '66.9237'}, 'latest': {'confirmed': 216964, 'deaths': 2891, 'recovered': 0}}
# {'id': 157, 'country': 'Kenya', 'country_code': 'KE', 'country_population': 51393010, 'province': '', 'last_updated': '2021-01-19T12:40:57.494954Z', 'coordinates': {'latitude': '-0.0236', 'longitude': '37.9062'}, 'latest': {'confirmed': 99227, 'deaths': 1734, 'recovered': 0}}
# {'id': 158, 'country': 'Korea, South', 'country_code': 'KR', 'country_population': 51635256, 'province': '', 'last_updated': '2021-01-19T12:40:57.545781Z', 'coordinates': {'latitude': '35.907757', 'longitude': '127.766922'}, 'latest': {'confirmed': 73115, 'deaths': 1283, 'recovered': 0}}
# {'id': 159, 'country': 'Kosovo', 'country_code': 'XK', 'country_population': 1845300, 'province': '', 'last_updated': '2021-01-19T12:40:57.615337Z', 'coordinates': {'latitude': '42.602636', 'longitude': '20.902977'}, 'latest': {'confirmed': 55851, 'deaths': 1410, 'recovered': 0}}
# {'id': 160, 'country': 'Kuwait', 'country_code': 'KW', 'country_population': 4137309, 'province': '', 'last_updated': '2021-01-19T12:40:57.663677Z', 'coordinates': {'latitude': '29.31166', 'longitude': '47.481766'}, 'latest': {'confirmed': 158244, 'deaths': 948, 'recovered': 0}}
# {'id': 161, 'country': 'Kyrgyzstan', 'country_code': 'KG', 'country_population': 6315800, 'province': '', 'last_updated': '2021-01-19T12:40:57.703131Z', 'coordinates': {'latitude': '41.20438', 'longitude': '74.766098'}, 'latest': {'confirmed': 83178, 'deaths': 1387, 'recovered': 0}}
# {'id': 162, 'country': 'Laos', 'country_code': 'LA', 'country_population': 7061507, 'province': '', 'last_updated': '2021-01-19T12:40:57.767350Z', 'coordinates': {'latitude': '19.85627', 'longitude': '102.495496'}, 'latest': {'confirmed': 41, 'deaths': 0, 'recovered': 0}}
# {'id': 163, 'country': 'Latvia', 'country_code': 'LV', 'country_population': 1926542, 'province': '', 'last_updated': '2021-01-19T12:40:57.876269Z', 'coordinates': {'latitude': '56.8796', 'longitude': '24.6032'}, 'latest': {'confirmed': 55908, 'deaths': 983, 'recovered': 0}}
# {'id': 164, 'country': 'Lebanon', 'country_code': 'LB', 'country_population': 6848925, 'province': '', 'last_updated': '2021-01-19T12:40:58.027662Z', 'coordinates': {'latitude': '33.8547', 'longitude': '35.8623'}, 'latest': {'confirmed': 255956, 'deaths': 1959, 'recovered': 0}}
# {'id': 165, 'country': 'Lesotho', 'country_code': 'LS', 'country_population': 2108132, 'province': '', 'last_updated': '2021-01-19T12:40:58.096832Z', 'coordinates': {'latitude': '-29.61', 'longitude': '28.2336'}, 'latest': {'confirmed': 7018, 'deaths': 101, 'recovered': 0}}
# {'id': 166, 'country': 'Liberia', 'country_code': 'LR', 'country_population': 4818977, 'province': '', 'last_updated': '2021-01-19T12:40:58.170637Z', 'coordinates': {'latitude': '6.428055', 'longitude': '-9.429499'}, 'latest': {'confirmed': 1896, 'deaths': 84, 'recovered': 0}}
# {'id': 167, 'country': 'Libya', 'country_code': 'LY', 'country_population': 6678567, 'province': '', 'last_updated': '2021-01-19T12:40:58.270678Z', 'coordinates': {'latitude': '26.3351', 'longitude': '17.228331'}, 'latest': {'confirmed': 109869, 'deaths': 1698, 'recovered': 0}}
# {'id': 168, 'country': 'Liechtenstein', 'country_code': 'LI', 'country_population': 37910, 'province': '', 'last_updated': '2021-01-19T12:40:58.319315Z', 'coordinates': {'latitude': '47.14', 'longitude': '9.55'}, 'latest': {'confirmed': 2395, 'deaths': 50, 'recovered': 0}}
# {'id': 169, 'country': 'Lithuania', 'country_code': 'LT', 'country_population': 2789533, 'province': '', 'last_updated': '2021-01-19T12:40:58.380343Z', 'coordinates': {'latitude': '55.1694', 'longitude': '23.8813'}, 'latest': {'confirmed': 167992, 'deaths': 2469, 'recovered': 0}}
# ...
# {'id': 216, 'country': 'Saint Vincent and the Grenadines', 'country_code': 'VC', 'country_population': 110211, 'province': '', 'last_updated': '2021-01-19T12:41:01.056259Z', 'coordinates': {'latitude': '12.9843', 'longitude': '-61.2872'}, 'latest': {'confirmed': 494, 'deaths': 1, 'recovered': 0}}
# {'id': 217, 'country': 'Samoa', 'country_code': 'WS', 'country_population': 196130, 'province': '', 'last_updated': '2021-01-19T12:41:01.105479Z', 'coordinates': {'latitude': '-13.759', 'longitude': '-172.1046'}, 'latest': {'confirmed': 2, 'deaths': 0, 'recovered': 0}}
# {'id': 218, 'country': 'San Marino', 'country_code': 'SM', 'country_population': 33785, 'province': '', 'last_updated': '2021-01-19T12:41:01.149740Z', 'coordinates': {'latitude': '43.9424', 'longitude': '12.4578'}, 'latest': {'confirmed': 2787, 'deaths': 65, 'recovered': 0}}
# {'id': 219, 'country': 'Sao Tome and Principe', 'country_code': 'ST', 'country_population': 197700, 'province': '', 'last_updated': '2021-01-19T12:41:01.194353Z', 'coordinates': {'latitude': '0.1864', 'longitude': '6.6131'}, 'latest': {'confirmed': 1142, 'deaths': 17, 'recovered': 0}}
# {'id': 220, 'country': 'Saudi Arabia', 'country_code': 'SA', 'country_population': 33699947, 'province': '', 'last_updated': '2021-01-19T12:41:01.239660Z', 'coordinates': {'latitude': '23.885942', 'longitude': '45.079162'}, 'latest': {'confirmed': 365099, 'deaths': 6329, 'recovered': 0}}
# {'id': 221, 'country': 'Senegal', 'country_code': 'SN', 'country_population': 15854360, 'province': '', 'last_updated': '2021-01-19T12:41:01.285420Z', 'coordinates': {'latitude': '14.4974', 'longitude': '-14.4524'}, 'latest': {'confirmed': 23224, 'deaths': 526, 'recovered': 0}}
# {'id': 222, 'country': 'Serbia', 'country_code': 'RS', 'country_population': 6982084, 'province': '', 'last_updated': '2021-01-19T12:41:01.337319Z', 'coordinates': {'latitude': '44.0165', 'longitude': '21.0059'}, 'latest': {'confirmed': 374111, 'deaths': 3771, 'recovered': 0}}
# {'id': 223, 'country': 'Seychelles', 'country_code': 'SC', 'country_population': 96762, 'province': '', 'last_updated': '2021-01-19T12:41:01.385949Z', 'coordinates': {'latitude': '-4.6796', 'longitude': '55.492'}, 'latest': {'confirmed': 746, 'deaths': 2, 'recovered': 0}}
# {'id': 224, 'country': 'Sierra Leone', 'country_code': 'SL', 'country_population': 7650154, 'province': '', 'last_updated': '2021-01-19T12:41:01.434235Z', 'coordinates': {'latitude': '8.460555', 'longitude': '-11.779889'}, 'latest': {'confirmed': 3014, 'deaths': 77, 'recovered': 0}}
# {'id': 225, 'country': 'Singapore', 'country_code': 'SG', 'country_population': 5638676, 'province': '', 'last_updated': '2021-01-19T12:41:01.481576Z', 'coordinates': {'latitude': '1.2833', 'longitude': '103.8333'}, 'latest': {'confirmed': 59127, 'deaths': 29, 'recovered': 0}}
# {'id': 226, 'country': 'Slovakia', 'country_code': 'SK', 'country_population': 5447011, 'province': '', 'last_updated': '2021-01-19T12:41:01.529570Z', 'coordinates': {'latitude': '48.669', 'longitude': '19.699'}, 'latest': {'confirmed': 224385, 'deaths': 3526, 'recovered': 0}}
# {'id': 227, 'country': 'Slovenia', 'country_code': 'SI', 'country_population': 2067372, 'province': '', 'last_updated': '2021-01-19T12:41:01.579915Z', 'coordinates': {'latitude': '46.1512', 'longitude': '14.9955'}, 'latest': {'confirmed': 149424, 'deaths': 3206, 'recovered': 0}}
# {'id': 228, 'country': 'Solomon Islands', 'country_code': 'SB', 'country_population': 652858, 'province': '', 'last_updated': '2021-01-19T12:41:01.629379Z', 'coordinates': {'latitude': '-9.6457', 'longitude': '160.1562'}, 'latest': {'confirmed': 17, 'deaths': 0, 'recovered': 0}}
# {'id': 229, 'country': 'Somalia', 'country_code': 'SO', 'country_population': 15008154, 'province': '', 'last_updated': '2021-01-19T12:41:01.682281Z', 'coordinates': {'latitude': '5.152149', 'longitude': '46.199616'}, 'latest': {'confirmed': 4744, 'deaths': 130, 'recovered': 0}}
# {'id': 230, 'country': 'South Africa', 'country_code': 'ZA', 'country_population': 57779622, 'province': '', 'last_updated': '2021-01-19T12:41:01.751284Z', 'coordinates': {'latitude': '-30.5595', 'longitude': '22.9375'}, 'latest': {'confirmed': 1346936, 'deaths': 37449, 'recovered': 0}}
# {'id': 231, 'country': 'South Sudan', 'country_code': 'SS', 'country_population': 8260490, 'province': '', 'last_updated': '2021-01-19T12:41:01.817651Z', 'coordinates': {'latitude': '6.877', 'longitude': '31.307'}, 'latest': {'confirmed': 3703, 'deaths': 63, 'recovered': 0}}
# {'id': 232, 'country': 'Spain', 'country_code': 'ES', 'country_population': 46723749, 'province': '', 'last_updated': '2021-01-19T12:41:01.946905Z', 'coordinates': {'latitude': '40.463667', 'longitude': '-3.74922'}, 'latest': {'confirmed': 2336451, 'deaths': 53769, 'recovered': 0}}
# {'id': 233, 'country': 'Sri Lanka', 'country_code': 'LK', 'country_population': 21670000, 'province': '', 'last_updated': '2021-01-19T12:41:02.117724Z', 'coordinates': {'latitude': '7.873054', 'longitude': '80.771797'}, 'latest': {'confirmed': 53750, 'deaths': 270, 'recovered': 0}}
# {'id': 234, 'country': 'Sudan', 'country_code': 'SD', 'country_population': 41801533, 'province': '', 'last_updated': '2021-01-19T12:41:02.210575Z', 'coordinates': {'latitude': '12.8628', 'longitude': '30.2176'}, 'latest': {'confirmed': 26279, 'deaths': 1603, 'recovered': 0}}
# {'id': 235, 'country': 'Suriname', 'country_code': 'SR', 'country_population': 575991, 'province': '', 'last_updated': '2021-01-19T12:41:02.274242Z', 'coordinates': {'latitude': '3.9193', 'longitude': '-56.0278'}, 'latest': {'confirmed': 7624, 'deaths': 145, 'recovered': 0}}
# {'id': 236, 'country': 'Sweden', 'country_code': 'SE', 'country_population': 10183175, 'province': '', 'last_updated': '2021-01-19T12:41:02.430026Z', 'coordinates': {'latitude': '60.128161', 'longitude': '18.643501'}, 'latest': {'confirmed': 523486, 'deaths': 10323, 'recovered': 0}}
# {'id': 237, 'country': 'Switzerland', 'country_code': 'CH', 'country_population': 8516543, 'province': '', 'last_updated': '2021-01-19T12:41:02.515337Z', 'coordinates': {'latitude': '46.8182', 'longitude': '8.2275'}, 'latest': {'confirmed': 499931, 'deaths': 8792, 'recovered': 0}}
# {'id': 238, 'country': 'Syria', 'country_code': 'SY', 'country_population': 16906283, 'province': '', 'last_updated': '2021-01-19T12:41:02.564599Z', 'coordinates': {'latitude': '34.802075', 'longitude': '38.996815'}, 'latest': {'confirmed': 13132, 'deaths': 841, 'recovered': 0}}
# {'id': 239, 'country': 'Taiwan*', 'country_code': 'TW', 'country_population': 22894384, 'province': '', 'last_updated': '2021-01-19T12:41:02.666467Z', 'coordinates': {'latitude': '23.7', 'longitude': '121.0'}, 'latest': {'confirmed': 862, 'deaths': 7, 'recovered': 0}}
# {'id': 240, 'country': 'Tajikistan', 'country_code': 'TJ', 'country_population': 9100837, 'province': '', 'last_updated': '2021-01-19T12:41:02.767366Z', 'coordinates': {'latitude': '38.861', 'longitude': '71.2761'}, 'latest': {'confirmed': 13308, 'deaths': 90, 'recovered': 0}}
# {'id': 241, 'country': 'Tanzania', 'country_code': 'TZ', 'country_population': 56318348, 'province': '', 'last_updated': '2021-01-19T12:41:02.933622Z', 'coordinates': {'latitude': '-6.369028', 'longitude': '34.888822'}, 'latest': {'confirmed': 509, 'deaths': 21, 'recovered': 0}}
# {'id': 242, 'country': 'Thailand', 'country_code': 'TH', 'country_population': 69428524, 'province': '', 'last_updated': '2021-01-19T12:41:03.041055Z', 'coordinates': {'latitude': '15.870032', 'longitude': '100.992541'}, 'latest': {'confirmed': 12594, 'deaths': 70, 'recovered': 0}}
# {'id': 243, 'country': 'Timor-Leste', 'country_code': 'TL', 'country_population': 1267972, 'province': '', 'last_updated': '2021-01-19T12:41:03.163965Z', 'coordinates': {'latitude': '-8.874217', 'longitude': '125.727539'}, 'latest': {'confirmed': 52, 'deaths': 0, 'recovered': 0}}
# {'id': 244, 'country': 'Togo', 'country_code': 'TG', 'country_population': 7889094, 'province': '', 'last_updated': '2021-01-19T12:41:03.290847Z', 'coordinates': {'latitude': '8.6195', 'longitude': '0.8248'}, 'latest': {'confirmed': 4324, 'deaths': 74, 'recovered': 0}}
# {'id': 245, 'country': 'Trinidad and Tobago', 'country_code': 'TT', 'country_population': 1389858, 'province': '', 'last_updated': '2021-01-19T12:41:03.368651Z', 'coordinates': {'latitude': '10.6918', 'longitude': '-61.2225'}, 'latest': {'confirmed': 7399, 'deaths': 132, 'recovered': 0}}
# {'id': 246, 'country': 'Tunisia', 'country_code': 'TN', 'country_population': 11565204, 'province': '', 'last_updated': '2021-01-19T12:41:03.462472Z', 'coordinates': {'latitude': '33.886917', 'longitude': '9.537499'}, 'latest': {'confirmed': 181885, 'deaths': 5750, 'recovered': 0}}
# {'id': 247, 'country': 'Turkey', 'country_code': 'TR', 'country_population': 82319724, 'province': '', 'last_updated': '2021-01-19T12:41:03.537917Z', 'coordinates': {'latitude': '38.9637', 'longitude': '35.2433'}, 'latest': {'confirmed': 2392963, 'deaths': 24161, 'recovered': 0}}
# {'id': 248, 'country': 'US', 'country_code': 'US', 'country_population': 327167434, 'province': '', 'last_updated': '2021-01-19T12:41:03.601210Z', 'coordinates': {'latitude': '40.0', 'longitude': '-100.0'}, 'latest': {'confirmed': 24078772, 'deaths': 399003, 'recovered': 0}}
# {'id': 249, 'country': 'Uganda', 'country_code': 'UG', 'country_population': 42723139, 'province': '', 'last_updated': '2021-01-19T12:41:03.722719Z', 'coordinates': {'latitude': '1.373333', 'longitude': '32.290275'}, 'latest': {'confirmed': 38085, 'deaths': 304, 'recovered': 0}}
# {'id': 250, 'country': 'Ukraine', 'country_code': 'UA', 'country_population': 44622516, 'province': '', 'last_updated': '2021-01-19T12:41:03.789570Z', 'coordinates': {'latitude': '48.3794', 'longitude': '31.1656'}, 'latest': {'confirmed': 1201894, 'deaths': 21847, 'recovered': 0}}
# {'id': 251, 'country': 'United Arab Emirates', 'country_code': 'AE', 'country_population': 9630959, 'province': '', 'last_updated': '2021-01-19T12:41:03.834462Z', 'coordinates': {'latitude': '23.424076', 'longitude': '53.847818'}, 'latest': {'confirmed': 256732, 'deaths': 751, 'recovered': 0}}
# {'id': 252, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Anguilla', 'last_updated': '2021-01-19T12:41:03.876675Z', 'coordinates': {'latitude': '18.2206', 'longitude': '-63.0686'}, 'latest': {'confirmed': 15, 'deaths': 0, 'recovered': 0}}
# {'id': 253, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Bermuda', 'last_updated': '2021-01-19T12:41:03.958670Z', 'coordinates': {'latitude': '32.3078', 'longitude': '-64.7505'}, 'latest': {'confirmed': 683, 'deaths': 12, 'recovered': 0}}
# {'id': 254, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'British Virgin Islands', 'last_updated': '2021-01-19T12:41:04.041056Z', 'coordinates': {'latitude': '18.4207', 'longitude': '-64.64'}, 'latest': {'confirmed': 114, 'deaths': 1, 'recovered': 0}}
# {'id': 255, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Cayman Islands', 'last_updated': '2021-01-19T12:41:04.093449Z', 'coordinates': {'latitude': '19.3133', 'longitude': '-81.2546'}, 'latest': {'confirmed': 380, 'deaths': 2, 'recovered': 0}}
# {'id': 256, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Channel Islands', 'last_updated': '2021-01-19T12:41:04.142615Z', 'coordinates': {'latitude': '49.3723', 'longitude': '-2.3644'}, 'latest': {'confirmed': 3370, 'deaths': 78, 'recovered': 0}}
# {'id': 257, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Falkland Islands (Malvinas)', 'last_updated': '2021-01-19T12:41:04.194468Z', 'coordinates': {'latitude': '-51.7963', 'longitude': '-59.5236'}, 'latest': {'confirmed': 32, 'deaths': 0, 'recovered': 0}}
# {'id': 258, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Gibraltar', 'last_updated': '2021-01-19T12:41:04.250988Z', 'coordinates': {'latitude': '36.1408', 'longitude': '-5.3536'}, 'latest': {'confirmed': 3712, 'deaths': 45, 'recovered': 0}}
# {'id': 259, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Isle of Man', 'last_updated': '2021-01-19T12:41:04.304320Z', 'coordinates': {'latitude': '54.2361', 'longitude': '-4.5481'}, 'latest': {'confirmed': 432, 'deaths': 25, 'recovered': 0}}
# {'id': 260, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Montserrat', 'last_updated': '2021-01-19T12:41:04.353636Z', 'coordinates': {'latitude': '16.742498', 'longitude': '-62.187366'}, 'latest': {'confirmed': 13, 'deaths': 1, 'recovered': 0}}
# {'id': 261, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': 'Turks and Caicos Islands', 'last_updated': '2021-01-19T12:41:04.401694Z', 'coordinates': {'latitude': '21.694', 'longitude': '-71.7979'}, 'latest': {'confirmed': 1105, 'deaths': 7, 'recovered': 0}}
# {'id': 262, 'country': 'United Kingdom', 'country_code': 'GB', 'country_population': 66488991, 'province': '', 'last_updated': '2021-01-19T12:41:04.453772Z', 'coordinates': {'latitude': '55.3781', 'longitude': '-3.436'}, 'latest': {'confirmed': 3433494, 'deaths': 89860, 'recovered': 0}}
# {'id': 263, 'country': 'Uruguay', 'country_code': 'UY', 'country_population': 3449299, 'province': '', 'last_updated': '2021-01-19T12:41:04.506011Z', 'coordinates': {'latitude': '-32.5228', 'longitude': '-55.7658'}, 'latest': {'confirmed': 32863, 'deaths': 319, 'recovered': 0}}
# {'id': 264, 'country': 'Uzbekistan', 'country_code': 'UZ', 'country_population': 32955400, 'province': '', 'last_updated': '2021-01-19T12:41:04.554502Z', 'coordinates': {'latitude': '41.377491', 'longitude': '64.585262'}, 'latest': {'confirmed': 78036, 'deaths': 619, 'recovered': 0}}
# {'id': 265, 'country': 'Vanuatu', 'country_code': 'VU', 'country_population': 292680, 'province': '', 'last_updated': '2021-01-19T12:41:04.605602Z', 'coordinates': {'latitude': '-15.3767', 'longitude': '166.9592'}, 'latest': {'confirmed': 1, 'deaths': 0, 'recovered': 0}}
# {'id': 266, 'country': 'Venezuela', 'country_code': 'VE', 'country_population': 28870195, 'province': '', 'last_updated': '2021-01-19T12:41:04.710109Z', 'coordinates': {'latitude': '6.4238', 'longitude': '-66.5897'}, 'latest': {'confirmed': 120444, 'deaths': 1112, 'recovered': 0}}
# {'id': 267, 'country': 'Vietnam', 'country_code': 'VN', 'country_population': 95540395, 'province': '', 'last_updated': '2021-01-19T12:41:04.758670Z', 'coordinates': {'latitude': '14.058324', 'longitude': '108.277199'}, 'latest': {'confirmed': 1539, 'deaths': 35, 'recovered': 0}}
# {'id': 268, 'country': 'West Bank and Gaza', 'country_code': 'PS', 'country_population': 4569087, 'province': '', 'last_updated': '2021-01-19T12:41:04.869626Z', 'coordinates': {'latitude': '31.9522', 'longitude': '35.2332'}, 'latest': {'confirmed': 152555, 'deaths': 1726, 'recovered': 0}}
# {'id': 269, 'country': 'Yemen', 'country_code': 'YE', 'country_population': 28498687, 'province': '', 'last_updated': '2021-01-19T12:41:04.918221Z', 'coordinates': {'latitude': '15.552727', 'longitude': '48.516388'}, 'latest': {'confirmed': 2113, 'deaths': 612, 'recovered': 0}}
# {'id': 270, 'country': 'Zambia', 'country_code': 'ZM', 'country_population': 17351822, 'province': '', 'last_updated': '2021-01-19T12:41:04.963171Z', 'coordinates': {'latitude': '-13.133897', 'longitude': '27.849332'}, 'latest': {'confirmed': 38207, 'deaths': 559, 'recovered': 0}}
# {'id': 271, 'country': 'Zimbabwe', 'country_code': 'ZW', 'country_population': 14439018, 'province': '', 'last_updated': '2021-01-19T12:41:05.014627Z', 'coordinates': {'latitude': '-19.015438', 'longitude': '29.154857'}, 'latest': {'confirmed': 27892, 'deaths': 773, 'recovered': 0}}
